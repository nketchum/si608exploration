# %%
import pandas as pd
import numpy as np
import networkx as nx
import plotly.graph_objects as go

# %%
usb_path = "../../data/open_secrets/"

# %%
#load campaign finance for candidates
columns_campfin22_cands22 = ['cycle', 'feccandid', 'cid', 'firstlastp', 'party', 'distidrunfor', 
                    'distidcurr', 'currcand', 'cyclecand', 'crpico', 'recipcode', 
                    'nopacs']
columns_campfin22_cands22 = dict(enumerate(columns_campfin22_cands22))

df_cand = pd.read_csv(usb_path + 'CampaignFin22/cands22.csv', on_bad_lines='skip', sep=',', header=None, na_values=['N/A', 'NA'])
df_cand = df_cand.rename(columns=columns_campfin22_cands22)
df_cand = df_cand.applymap(lambda x: x.strip('|') if isinstance(x, str) else x)
df_cand.head()
# Out:
# /var/folders/5c/qtn4glhd0t7819wv3q972_dh0000gn/T/ipykernel_21463/1200312228.py:9: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_cand = df_cand.applymap(lambda x: x.strip('|') if isinstance(x, str) else x)
#   cycle  feccandid        cid          firstlastp party distidrunfor  \
# 0  2022  H0AK00105  N00039029     Thomas Lamb (3)     3         AK01
# 1  2022  H0AL01055  N00044245      Jerry Carl (R)     R         AL01
# 2  2022  H0AL01063  N00044288     Wes Lambert (R)     R         AL01
# 3  2022  H0AL01097  N00044750  James Averhart (D)     D         AL01
# 4  2022  H0AL02087  N00030768     Martha Roby (R)     R         AL02
#
#   distidcurr currcand cyclecand crpico recipcode nopacs
# 0                                             3N
# 1       AL01        Y         Y      I        RW
# 2                                             RN
# 3                                             DN
# 4                                             RN

# %%
#load campaign finance for pacs
columns_campfin22_pacs22 = ['cycle', 'fecrecno', 'pacid', 'cid', 'amount', 'date', 'realcode', 
                            'type', 'di', 'feccandid']
columns_campfin22_pacs22 = dict(enumerate(columns_campfin22_pacs22))

df_pacs = pd.read_csv(usb_path + 'CampaignFin22/pacs22.csv', on_bad_lines='skip', sep=',', header=None, na_values=['N/A', 'NA'])

df_pacs = df_pacs.rename(columns=columns_campfin22_pacs22)
df_pacs = df_pacs.applymap(lambda x: x.strip('|') if isinstance(x, str) else x)
df_pacs.head()
# Out:
# /var/folders/5c/qtn4glhd0t7819wv3q972_dh0000gn/T/ipykernel_21463/3318265269.py:9: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_pacs = df_pacs.applymap(lambda x: x.strip('|') if isinstance(x, str) else x)
#   cycle             fecrecno      pacid        cid  amount        date  \
# 0  2022  1011020220264924462  C00406124  N00029513     500  10/18/2021
# 1  2022  1011320230265253020  C00032979  N00041569   -2500  11/21/2022
# 2  2022  1011320230265254779  C00032979  N00041511   -5000  11/18/2022
# 3  2022  1011320230265254798  C00032979  N00035575    5000  11/03/2022
# 4  2022  1011320230265254809  C00032979  N00041511    4000  11/03/2022
#
#   realcode type di  feccandid
# 0    B4000  24K  D  H8IN07184
# 1    Z9600  24K  D  H8IL14174
# 2    Z9600  24K  D  H8MN08043
# 3    Z9600  24K  D  H4FL15155
# 4    Z9600  24K  D  H8MN08043

# %%
#load campaign finance for committees
columns_campfin22_cmtes22 = ['cycle', 'cmteid', 'pacshort', 'affiliate', 'ultorg', 'recipid', 
                    'recipcode', 'feccandid', 'party', 'primcode', 'source', 'sensitive',
                    'foreign', 'active']
columns_campfin22_cmtes22 = dict(enumerate(columns_campfin22_cmtes22))
# usb_path = "../../../"
df_cmt = pd.read_csv(usb_path + 'CampaignFin22/cmtes22.csv', on_bad_lines='skip', sep=',', header=None, na_values=['N/A', 'NA'])
df_cmt = df_cmt.rename(columns=columns_campfin22_cmtes22)
df_cmt = df_cmt.applymap(lambda x: x.strip('|') if isinstance(x, str) else x)
df_cmt.head()
# Out:
# /var/folders/5c/qtn4glhd0t7819wv3q972_dh0000gn/T/ipykernel_21463/1117515397.py:9: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_cmt = df_cmt.applymap(lambda x: x.strip('|') if isinstance(x, str) else x)
#   cycle     cmteid                                           pacshort  \
# 0  2022  C00000059                                     Hallmark Cards
# 1  2022  C00000422                              American Medical Assn
# 2  2022  C00000489                                Teamsters Local 886
# 3  2022  C00000547  KANSAS MEDICAL SOCIETY POLITICAL ACTION COMMIT...
# 4  2022  C00000729                               American Dental Assn
#
#                affiliate                 ultorg    recipid recipcode  \
# 0                    NaN         Hallmark Cards  C00000059        PB
# 1  American Medical Assn  American Medical Assn  C00000422        PB
# 2        Teamsters Union        Teamsters Union  C00000489        PL
# 3                    NaN                    NaN  C00000547       NaN
# 4   American Dental Assn   American Dental Assn  C00000729        PB
#
#   feccandid party primcode source sensitive foreign  active
# 0       NaN   NaN    C1400  WAA21         Y       0       1
# 1       NaN   NaN    H1100  WAA21         n       0       1
# 2       NaN          LT300  WAA21         n       0       1
# 3       NaN     U      NaN    NaN       NaN       0       0
# 4       NaN   NaN    H1400  WAA21         n       0       1

# %%
#find candidates on the ways and means committee
ways_and_means_members = ["Earl Blumenauer", "Don Beyer"]
df_cand['firstlastp'] = df_cand['firstlastp'].apply(lambda x: ' '.join(x.split()[:2]))
df_cand_filt = df_cand[df_cand['firstlastp'].isin(ways_and_means_members)]
df_cand_filt.head()
# Out:
#      cycle  feccandid        cid       firstlastp party distidrunfor  \
# 5031  2022  H4VA08224  N00036018        Don Beyer     D         VA08
# 5294  2022  H6OR03064  N00007727  Earl Blumenauer     D         OR03
#
#      distidcurr currcand cyclecand crpico recipcode nopacs
# 5031       VA08        Y         Y      I        DW
# 5294       OR03        Y         Y      I        DW

# %%
#Ways and Means PACs
df_pacs_wm = df_pacs.merge(df_cand_filt.set_index('feccandid'), on=['feccandid', 'cid'])
df_pacs_wm.head()
# Out:
#   cycle_x             fecrecno      pacid        cid  amount        date  \
# 0    2022  1081920220264974933  C00024521  N00036018    3000  07/29/2022
# 1    2022  2022820231732873145  C00529966  N00007727    1500  10/17/2022
# 2    2022  2031520231734695065  C00529966  N00007727    1500  10/17/2022
# 3    2022  2081820221565471064  C00207969  N00007727    1000  04/07/2022
# 4    2022  4010420231646810024  C00032995  N00007727    5000  10/20/2022
#
#   realcode type di  feccandid cycle_y       firstlastp party distidrunfor  \
# 0    K1100  24K  D  H4VA08224    2022        Don Beyer     D         VA08
# 1    T5100  24K  D  H6OR03064    2022  Earl Blumenauer     D         OR03
# 2    Z9600  24K  D  H6OR03064    2022  Earl Blumenauer     D         OR03
# 3    G3500  24K  D  H6OR03064    2022  Earl Blumenauer     D         OR03
# 4    LT000  24K  D  H6OR03064    2022  Earl Blumenauer     D         OR03
#
#   distidcurr currcand cyclecand crpico recipcode nopacs
# 0       VA08        Y         Y      I        DW
# 1       OR03        Y         Y      I        DW
# 2       OR03        Y         Y      I        DW
# 3       OR03        Y         Y      I        DW
# 4       OR03        Y         Y      I        DW

# %%
#merge pac information with candidate personal identifiers
df_cmt_filt = df_cmt[["cmteid", "pacshort", "affiliate", "ultorg", "primcode"]]
df_pacs_wm_cmt = df_pacs_wm.merge(df_cmt_filt.set_index('cmteid'), left_on='pacid', right_on='cmteid')
df_pacs_wm_cmt["quarter"] = pd.to_datetime(df_pacs_wm_cmt["date"]).dt.to_period("Q")
df_pacs_wm_cmt["year"] = pd.to_datetime(df_pacs_wm_cmt["date"]).dt.year
df_pacs_wm_cmt[["pacid", "pacshort", "ultorg", "cid", "firstlastp", "party", "date", "year", "quarter", "amount"]]
# Out:
#          pacid                                         pacshort  \
# 0    C00024521                        American Assn for Justice
# 1    C00529966                       Florida East Coast Railway
# 2    C00529966                       Florida East Coast Railway
# 3    C00207969      National Customs Brokers & Forwarders Assn
# 4    C00032995                        Amalgamated Transit Union
# ..         ...                                              ...
# 735  C00235739                                     BNSF Railway
# 736  C00034405                              International Paper
# 737  C00118943              Massachusetts Mutual Life Insurance
# 738  C00005249  National Assn of Insurance & Financial Advisors
# 739  C00196246                American Academy of Ophthalmology
#
#                                               ultorg        cid  \
# 0                          American Assn for Justice  N00036018
# 1                                       Grupo Mexico  N00007727
# 2                                       Grupo Mexico  N00007727
# 3        National Customs Brokers & Forwarders Assn   N00007727
# 4                          Amalgamated Transit Union  N00007727
# ..                                               ...        ...
# 735                               Berkshire Hathaway  N00007727
# 736                              International Paper  N00007727
# 737              Massachusetts Mutual Life Insurance  N00036018
# 738  National Assn of Insurance & Financial Advisors  N00036018
# 739                American Academy of Ophthalmology  N00007727
#
#           firstlastp party        date  year quarter  amount
# 0          Don Beyer     D  07/29/2022  2022  2022Q3    3000
# 1    Earl Blumenauer     D  10/17/2022  2022  2022Q4    1500
# 2    Earl Blumenauer     D  10/17/2022  2022  2022Q4    1500
# 3    Earl Blumenauer     D  04/07/2022  2022  2022Q2    1000
# 4    Earl Blumenauer     D  10/20/2022  2022  2022Q4    5000
# ..               ...   ...         ...   ...     ...     ...
# 735  Earl Blumenauer     D  11/01/2021  2021  2021Q4    2000
# 736  Earl Blumenauer     D  11/16/2021  2021  2021Q4    2500
# 737        Don Beyer     D  11/12/2021  2021  2021Q4    5000
# 738        Don Beyer     D  11/17/2021  2021  2021Q4    2500
# 739  Earl Blumenauer     D  11/04/2021  2021  2021Q4    1500
#
# [740 rows x 10 columns]

# %%
#group pac committee contributions by candidate and quarter
df_pacs_wm_cmt_agg = df_pacs_wm_cmt.groupby(['ultorg', "cid", 'firstlastp', "year", "quarter"])["amount"].sum().reset_index().sort_values(by='amount', ascending=False)

# %%
df_pacs_wm_cmt_agg.head()
# Out:
#                        ultorg        cid       firstlastp  year quarter  \
# 566            PeopleForBikes  N00007727  Earl Blumenauer  2021  2021Q3
# 613                    SpaceX  N00036018        Don Beyer  2021  2021Q2
# 282                 ESOP Assn  N00036018        Don Beyer  2022  2022Q2
# 356  Humane Society of the US  N00007727  Earl Blumenauer  2022  2022Q4
# 202    Blue Cross/Blue Shield  N00007727  Earl Blumenauer  2021  2021Q3
#
#      amount
# 566   10000
# 613   10000
# 282   10000
# 356    7599
# 202    6000

# %%
# df_pacs_wm_cmt_agg = df_pacs_wm_cmt_agg.groupby(['ultorg','firstlastp'])["amount"].sum().reset_index().sort_values(by='amount', ascending=False)

# %%
# Dataset description:d
# https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20lob_lobbying.htm
columns_lob_lobbying = ['uniqid', 'registrant_raw', 'registrant', 'isfirm', 
                     'client_raw', 'client', 'ultorg', 'amount', 'catcode',
                     'source', 'self', 'includensfs', 'use', 'ind', 'year',
                     'type', 'typelong', 'affiliate']

columns_lob_lobbying = dict(enumerate(columns_lob_lobbying))

df_lobbying = pd.read_csv('../../data/open_secrets/Lobby/lob_lobbying.csv', on_bad_lines='skip', sep=',', header=None, na_values=['N/A', 'NA'], encoding='ISO-8859-1')
df_lobbying = df_lobbying.rename(columns=columns_lob_lobbying)
df_lobbying = df_lobbying.applymap(lambda x: x.strip('|') if isinstance(x, str) else x)
# Out:
# /var/folders/5c/qtn4glhd0t7819wv3q972_dh0000gn/T/ipykernel_21463/2194844689.py:10: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_lobbying = pd.read_csv('../../data/open_secrets/Lobby/lob_lobbying.csv', on_bad_lines='skip', sep=',', header=None, na_values=['N/A', 'NA'], encoding='ISO-8859-1')
# /var/folders/5c/qtn4glhd0t7819wv3q972_dh0000gn/T/ipykernel_21463/2194844689.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_lobbying = df_lobbying.applymap(lambda x: x.strip('|') if isinstance(x, str) else x)

# %%
# Dataset description:
# https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20lob_issues.htm
columns_lob_issue = ['si_id', 'uniqid', 'issueid', 'issue', 'specificissue', 5, 6, 7, 8, 9, 10, 'year']
columns_lob_issue = dict(enumerate(columns_lob_issue))
df_issue = pd.read_csv('../../data/open_secrets/Lobby/lob_issue.csv', on_bad_lines='skip', sep=',', header=None, na_values=['N/A', 'NA'], encoding='ISO-8859-1')
df_issue = df_issue.rename(columns=columns_lob_issue)
df_issue = df_issue.applymap(lambda x: x.replace('|', '') if type(x) == str else x)

# Other cleanup.
df_issue['year'] = pd.to_numeric(df_issue['year'], errors='coerce')
df_issue = df_issue.dropna(subset=['year'])
df_issue['year'] = df_issue['year'].astype(int)
# Out:
# /var/folders/5c/qtn4glhd0t7819wv3q972_dh0000gn/T/ipykernel_21463/3147263925.py:5: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_issue = pd.read_csv('../../data/open_secrets/Lobby/lob_issue.csv', on_bad_lines='skip', sep=',', header=None, na_values=['N/A', 'NA'], encoding='ISO-8859-1')
# /var/folders/5c/qtn4glhd0t7819wv3q972_dh0000gn/T/ipykernel_21463/3147263925.py:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_issue = df_issue.applymap(lambda x: x.replace('|', '') if type(x) == str else x)

# %%
# Dataset description:
# https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20lob_bills.htm
columns_lob_bills = ['b_id', 'si_id', 'congno', 'bill_name']

columns_lob_bills = dict(enumerate(columns_lob_bills))
df_bills = pd.read_csv('../../data/open_secrets/Lobby/lob_bills.csv', on_bad_lines='skip', sep=',', header=None, na_values=['N/A', 'NA'], encoding='ISO-8859-1')
df_bills = df_bills.rename(columns=columns_lob_bills)
# Get rid of the pipes on both sides of the data.
df_bills = df_bills.applymap(lambda x: x.replace('|', '') if type(x) == str else x)

# Other cleanup.
df_bills['congno'] = pd.to_numeric(df_bills['congno'], errors='coerce')
df_bills = df_bills.dropna(subset=['congno'])
df_bills['congno'] = df_bills['congno'].astype(int)
# Out:
# /var/folders/5c/qtn4glhd0t7819wv3q972_dh0000gn/T/ipykernel_21463/570261559.py:9: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_bills = df_bills.applymap(lambda x: x.replace('|', '') if type(x) == str else x)

# %%
df_bills.head()
# Out:
#          b_id    si_id  congno bill_name
# 0   s1461-117  2820018     117    S.1461
# 1   hr463-117  2820018     117   H.R.463
# 2    s910-116  2820035     116     S.910
# 3  hr2405-116  2820035     116  H.R.2405
# 4  hr3816-117  2820067     117  H.R.3816

# %%
df_issue.head()
# Out:
#      si_id                                uniqid issueid  \
# 0  3001624  02e92bd6-0159-495e-9d00-8a490a0be8be     DIS
# 1  3001625  02e92bd6-0159-495e-9d00-8a490a0be8be     ENV
# 2  3001627  02e92bd6-0159-495e-9d00-8a490a0be8be     ROD
# 3  3001628  02e92bd6-0159-495e-9d00-8a490a0be8be     RRR
# 4  3001629  02e92bd6-0159-495e-9d00-8a490a0be8be     TAX
#
#                            issue  \
# 0  Disaster & Emergency Planning
# 1        Environment & Superfund
# 2               Roads & Highways
# 3                      Railroads
# 4                          Taxes
#
#                                        specificissue               5  \
# 0  Issues affecting manufacturer of railroad and ...   environmental
# 1  Issues affecting manufacturer of railroad and ...   environmental
# 2  Issues affecting manufacturer of railroad and ...   environmental
# 3  Issues affecting manufacturer of railroad and ...   environmental
# 4  Issues affecting manufacturer of railroad and ...   environmental
#
#                  6       7       8          9  \
# 0   transportation   trade   labor   shipping
# 1   transportation   trade   labor   shipping
# 2   transportation   trade   labor   shipping
# 3   transportation   trade   labor   shipping
# 4   transportation   trade   labor   shipping
#
#                                    10  year
# 0   disaster planning and tax issues.  2022
# 1   disaster planning and tax issues.  2022
# 2   disaster planning and tax issues.  2022
# 3   disaster planning and tax issues.  2022
# 4   disaster planning and tax issues.  2022

# %%
df_lobbying.head()
# Out:
#                                  uniqid                        registrant_raw  \
# 0  82c5f661-a637-45ad-a3a6-b5ba18cf8962        ASTRAZENECA PHARMACEUTICALS LP
# 1  85b111b1-5d2e-4107-bc24-0921316e29a5            ECHELON GOVERNMENT AFFAIRS
# 2  87822a14-12de-478c-a34d-010fa503e539  WTA -- ADVOCATES FOR RURAL BROADBAND
# 3  87ff989d-9d12-4fef-84ef-ab69cd616894    FINANCIAL EXECUTIVES INTERNATIONAL
# 4  88bac485-00bb-4915-8ca5-8d0ec589ec28         CAPITOL HILL CONSULTING GROUP
#
#                             registrant isfirm  \
# 0          AstraZeneca Pharmaceuticals    NaN
# 1           Echelon Government Affairs      y
# 2  Western Telecommunications Alliance    NaN
# 3   Financial Executives International    NaN
# 4        Capitol Hill Consulting Group      y
#
#                                           client_raw  \
# 0                     ASTRAZENECA PHARMACEUTICALS LP
# 1                                   THE ALBERS GROUP
# 2               WTA -- ADVOCATES FOR RURAL BROADBAND
# 3                 FINANCIAL EXECUTIVES INTERNATIONAL
# 4  ASSOCIATION FOR ACCESSIBLE MEDICINES (FORMERLY...
#
#                                  client                                ultorg  \
# 0           AstraZeneca Pharmaceuticals                       AstraZeneca PLC
# 1                          Albers Group                          Albers Group
# 2   Western Telecommunications Alliance   Western Telecommunications Alliance
# 3    Financial Executives International    Financial Executives International
# 4  Association for Accessible Medicines  Association for Accessible Medicines
#
#       amount catcode source self includensfs use ind  year type  \
# 0  1370000.0   H4300  pac      x               y   y  2021  q4a
# 1    10000.0   Y4000           n               y   y  2021   q4
# 2    75000.0   C4000  pac      p               y   y  2021   q4
# 3    21650.0   F5000  Hvr06    p               y   y  2021   q4
# 4    40000.0   H4300  pac      i               y      2021   q4
#
#                    typelong affiliate
# 0  FOURTH QUARTER AMENDMENT
# 1     FOURTH QUARTER REPORT
# 2     FOURTH QUARTER REPORT
# 3     FOURTH QUARTER REPORT
# 4     FOURTH QUARTER REPORT

# %%
#load lobbying firms to agencies
columns_lob_agency = ['uniqid', 'agencyid', 'agency']
columns_lob_agency = dict(enumerate(columns_lob_agency))

df_agency = pd.read_csv('../../data/open_secrets/Lobby/lob_agency.csv', on_bad_lines='skip', sep=',', header=None, na_values=['N/A', 'NA'], encoding='ISO-8859-1')
df_agency = df_agency.rename(columns=columns_lob_agency)
df_agency = df_agency.applymap(lambda x: x.strip('|') if isinstance(x, str) else x)
# Out:
# /var/folders/5c/qtn4glhd0t7819wv3q972_dh0000gn/T/ipykernel_21463/1750360666.py:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_agency = df_agency.applymap(lambda x: x.strip('|') if isinstance(x, str) else x)

# %%
#find how many companies who finance campaigns also lobby
companies_in_both = (set(df_lobbying["registrant"]).intersection(set(df_pacs_wm_cmt["ultorg"])))
companies_no_lobbying = set(df_pacs_wm_cmt["ultorg"]).difference(set(df_lobbying["registrant"]))
print(len(companies_no_lobbying))
print(len(companies_in_both))
print("Percentage of companies that finance campaigns who also lobby: ",)
print(len(companies_in_both) / (len(companies_in_both) + len(companies_no_lobbying)))
# Out:
# 92
# 232
# Percentage of companies that finance campaigns who also lobby:
# 0.7160493827160493

# %%
df_pacs_wm_cmt_agg
# Out:
#                             ultorg        cid       firstlastp  year quarter  \
# 566                 PeopleForBikes  N00007727  Earl Blumenauer  2021  2021Q3
# 613                         SpaceX  N00036018        Don Beyer  2021  2021Q2
# 282                      ESOP Assn  N00036018        Don Beyer  2022  2022Q2
# 356       Humane Society of the US  N00007727  Earl Blumenauer  2022  2022Q4
# 202         Blue Cross/Blue Shield  N00007727  Earl Blumenauer  2021  2021Q3
# ..                             ...        ...              ...   ...     ...
# 386              Johnson & Johnson  N00036018        Don Beyer  2022  2022Q4
# 337                    Hawkeye 360  N00036018        Don Beyer  2022  2022Q3
# 50   America's Communications Assn  N00036018        Don Beyer  2021  2021Q2
# 310                 Friedkin Group  N00036018        Don Beyer  2022  2022Q4
# 253                 Crawford Group  N00036018        Don Beyer  2022  2022Q1
#
#      amount
# 566   10000
# 613   10000
# 282   10000
# 356    7599
# 202    6000
# ..      ...
# 386       0
# 337    -100
# 50    -1000
# 310   -1500
# 253   -2500
#
# [688 rows x 6 columns]

# %%
#get earliest financial contributions to committee members
min_quarter = df_pacs_wm_cmt_agg["quarter"].min()
min_quarter
# Out:
# Period('2021Q1', 'Q-DEC')

# %%
w_m_dems = ["Richard Neal",
"Brad Schneider",
"Jimmy Panetta",
"Bill Pascrell",
"Linda Sánchez",
"Terri Sewell",
"Gwen Moore",
"Tom Suozzi",
"Mike Thompson",
"John Larson",
"Stephanie Murphy",
"Donald Beyer",
"Earl Blumenauer",
"Brendan Boyle",
"Judy Chu",
"Danny Davis",
"Suzan DelBene",
"Lloyd Doggett",
"Dwight Evans",
"Jimmy Gomez",
"Brian Higgins",
"Steven Horsford",
"Dan Kildee",
"Ronald Kind"]

w_m_dems = pd.DataFrame(w_m_dems, columns=["firstlastp"])
w_m_dems.merge(df_cand, on="firstlastp", how="left")
# Out:
#           firstlastp cycle  feccandid        cid party distidrunfor  \
# 0       Richard Neal   NaN        NaN        NaN   NaN          NaN
# 1     Brad Schneider  2022  H2IL10068  N00033101     D         IL10
# 2      Jimmy Panetta  2022  H6CA20152  N00038601     D         CA19
# 3      Bill Pascrell  2022  H6NJ08118  N00000751     D         NJ09
# 4      Linda Sánchez   NaN        NaN        NaN   NaN          NaN
# 5       Terri Sewell  2022  H0AL07086  N00030622     D         AL07
# 6         Gwen Moore  2022  H4WI04183  N00026914     D         WI04
# 7         Tom Suozzi  2022  H6NY03247  N00038742     D         NY03
# 8      Mike Thompson  2022  H8CA01109  N00007419     D         CA04
# 9        John Larson  2022  H8CT01046  N00000575     D         CT01
# 10  Stephanie Murphy  2022  H6FL07140  N00040133     D         FL07
# 11      Donald Beyer   NaN        NaN        NaN   NaN          NaN
# 12   Earl Blumenauer  2022  H6OR03064  N00007727     D         OR03
# 13     Brendan Boyle  2022  H4PA13199  N00035307     D         PA02
# 14          Judy Chu  2022  H0CA32101  N00030600     D         CA28
# 15       Danny Davis   NaN        NaN        NaN   NaN          NaN
# 16     Suzan DelBene  2022  H0WA08046  N00030693     D         WA01
# 17     Lloyd Doggett  2022  H4TX10028  N00006023     D         TX37
# 18      Dwight Evans  2022  H6PA02171  N00038450     D         PA03
# 19       Jimmy Gomez  2022  H8CA34266  N00040597     D         CA34
# 20     Brian Higgins  2022  H4NY27076  N00027060     D         NY26
# 21   Steven Horsford  2022  H2NV04011  N00033638     D         NV04
# 22        Dan Kildee  2022  H2MI05119  N00033395     D         MI08
# 23       Ronald Kind   NaN        NaN        NaN   NaN          NaN
#
#    distidcurr currcand cyclecand crpico recipcode nopacs
# 0         NaN      NaN       NaN    NaN       NaN    NaN
# 1        IL10        Y         Y      I        DW
# 2        CA20        Y         Y      I        DW
# 3        NJ09        Y         Y      I        DW
# 4         NaN      NaN       NaN    NaN       NaN    NaN
# 5        AL07        Y         Y      I        DW
# 6        WI04        Y         Y      I        DW
# 7        NY03                         I        DI
# 8        CA05        Y         Y      I        DW
# 9        CT01        Y         Y      I        DW
# 10       FL07                         I        DI
# 11        NaN      NaN       NaN    NaN       NaN    NaN
# 12       OR03        Y         Y      I        DW
# 13       PA02        Y         Y      I        DW
# 14       CA27        Y         Y      I        DW
# 15        NaN      NaN       NaN    NaN       NaN    NaN
# 16       WA01        Y         Y      I        DW
# 17       TX35        Y         Y      I        DW
# 18       PA03        Y         Y      I        DW
# 19       CA34        Y         Y      I        DW
# 20       NY26        Y         Y      I        DW
# 21       NV04        Y         Y      I        DW
# 22       MI05        Y         Y      I        DW
# 23        NaN      NaN       NaN    NaN       NaN    NaN

# %%
wm_repub = ["Jason Smith", 
"Vern Buchanan",
"Kevin Hern",
"Lloyd Smucker",
"Mike Kelly",
"Nicole Malliotakis",
"Randy Feenstra",
"Jodey Arrington",
"Greg Steube",
"Ron Estes",
"Adrian Smith",
"Beth Van Duyne",
"Carol Miller",
"Michelle Fischbach",
"Michelle Steel",
"Mike Carey",
"Blake Moore",
"Brad Wenstrup",
"Brian Fitzpatrick",
"Claudia Tenney",
"Darin LaHood",
"David Kustoff",
"David Schweikert",
"Drew Ferguson",
"Gregory Murphy"]

wm_repub = pd.DataFrame(wm_repub, columns=["firstlastp"])
wm_repub["party"] = "R"
wm_repub.merge(df_cand, on=["firstlastp", "party"], how="left")
# Out:
#             firstlastp party cycle  feccandid        cid distidrunfor  \
# 0          Jason Smith     R  2022  H4MO08162  N00035282         MO08
# 1        Vern Buchanan     R   NaN        NaN        NaN          NaN
# 2           Kevin Hern     R  2022  H8OK01157  N00040829         OK01
# 3        Lloyd Smucker     R  2022  H6PA16320  N00038781         PA11
# 4           Mike Kelly     R  2022  H0PA03271  N00031647         PA16
# 5   Nicole Malliotakis     R  2022  H0NY11078  N00044040         NY11
# 6       Randy Feenstra     R  2022  H0IA04145  N00044011         IA04
# 7      Jodey Arrington     R  2022  H6TX19099  N00038285         TX19
# 8          Greg Steube     R  2022  H8FL17053  N00042808         FL17
# 9            Ron Estes     R  2022  H8KS04112  N00040712         KS04
# 10        Adrian Smith     R  2022  H6NE03115  N00027623         NE03
# 11      Beth Van Duyne     R   NaN        NaN        NaN          NaN
# 12        Carol Miller     R  2022  H8WV03097  N00041542         WV01
# 13  Michelle Fischbach     R  2022  H0MN07091  N00045251         MN07
# 14      Michelle Steel     R  2022  H0CA48198  N00044501         CA45
# 15          Mike Carey     R  2022  H2OH15228  N00048568         OH15
# 16         Blake Moore     R  2022  H0UT01205  N00046598         UT01
# 17       Brad Wenstrup     R  2022  H2OH02085  N00033310         OH02
# 18   Brian Fitzpatrick     R  2022  H6PA08277  N00038779         PA01
# 19      Claudia Tenney     R  2022  H4NY22051  N00036351         NY24
# 20        Darin LaHood     R  2022  H6IL18088  N00037031         IL16
# 21       David Kustoff     R  2022  H2TN07103  N00025445         TN08
# 22    David Schweikert     R  2022  H4AZ06045  N00006460         AZ01
# 23       Drew Ferguson     R  2022  H6GA03113  N00039090         GA03
# 24      Gregory Murphy     R   NaN        NaN        NaN          NaN
#
#    distidcurr currcand cyclecand crpico recipcode nopacs
# 0        MO08        Y         Y      I        RW
# 1         NaN      NaN       NaN    NaN       NaN    NaN
# 2        OK01        Y         Y      I        RW
# 3        PA11        Y         Y      I        RW
# 4        PA16        Y         Y      I        RW
# 5        NY11        Y         Y      I        RW
# 6        IA04        Y         Y      I        RW
# 7        TX19        Y         Y      I        RW
# 8        FL17        Y         Y      I        RW
# 9        KS04        Y         Y      I        RW
# 10       NE03        Y         Y      I        RW
# 11        NaN      NaN       NaN    NaN       NaN    NaN
# 12       WV03        Y         Y      I        RW
# 13       MN07        Y         Y      I        RW
# 14       CA48        Y         Y      I        RW
# 15       OH15        Y         Y      I        RW
# 16       UT01        Y         Y      I        RW
# 17       OH02        Y         Y      I        RW
# 18       PA01        Y         Y      I        RW
# 19       NY22        Y         Y      I        RW
# 20       IL18        Y         Y      I        RW
# 21       TN08        Y         Y      I        RW
# 22       AZ06        Y         Y      I        RW
# 23       GA03        Y         Y      I        RW
# 24        NaN      NaN       NaN    NaN       NaN    NaN

# %%
def finance_ways_means(df_cand, df_pacs, ways_and_means_members):
    df_cand['firstlastp'] = df_cand['firstlastp'].apply(lambda x: ' '.join(x.split()[:2]))
    df_cand_filt = df_cand[df_cand['firstlastp'].isin(ways_and_means_members)]

    df_pacs_wm = df_pacs.merge(df_cand_filt.set_index('feccandid'), on=['feccandid', 'cid'])

    #get pacs that have contributed to the ways and means committee
    df_cmt_filt = df_cmt[["cmteid", "pacshort", "affiliate", "ultorg", "primcode"]]
    df_pacs_wm_cmt = df_pacs_wm.merge(df_cmt_filt.set_index('cmteid'), left_on='pacid', right_on='cmteid')
    df_pacs_wm_cmt["quarter"] = pd.to_datetime(df_pacs_wm_cmt["date"]).dt.to_period("Q")
    df_pacs_wm_cmt["year"] = pd.to_datetime(df_pacs_wm_cmt["date"]).dt.year

    #get earliest financial contributions to committee members
    min_quarter = df_pacs_wm_cmt["quarter"].min()

    #get sum of pacs contributions to committee members
    df_pacs_wm_cmt_agg = df_pacs_wm_cmt.groupby(['ultorg', "cid", 'firstlastp'])["amount"].sum().reset_index().sort_values(by='amount', ascending=False)

    return df_pacs_wm_cmt_agg, min_quarter

# %%
def lobbying_committee(df_lobbying, df_agency, agency_id, df_pacs_wm_cmt, min_quarter):

    #process lobbying data for ways and means committee
    df_lobbying_filt = df_lobbying[["uniqid", "registrant", "client", "ultorg", "amount", "catcode", "year", "type"]]

    #only get lobbying firms lobbying house of representatives
    rep_lobbying = df_agency[df_agency["agencyid"] == agency_id]

    #merge agency data with general lobbying data
    df_lobbying_filt = df_lobbying_filt.merge(rep_lobbying.set_index('uniqid'), on='uniqid', how = "inner")

    df_lobbying_filt = df_lobbying_filt.merge(df_issue[["uniqid", "si_id"]], on='uniqid', how = "inner")

    df_lobbying_filt = df_lobbying_filt.merge(df_bills[["si_id", "b_id"]], on='si_id', how = "inner")

    #create quarter field and only include data from the earliest quarter of campaign finance data
    df_lobbying_filt['quarter'] =  df_lobbying_filt['year'].astype(str) + df_lobbying_filt['type'].str[:2].str.capitalize()
    df_lobbying_filt['quarter'] = pd.to_datetime(df_lobbying_filt['quarter'], errors='coerce').dt.to_period('Q-DEC')
    df_lobbying_filt = df_lobbying_filt[(df_lobbying_filt["quarter"] >= min_quarter)][["registrant", "ultorg", "amount", "quarter", "catcode", "b_id"]]

    #only include organizations that have contributed to the ways and means committee
    orgs = pd.DataFrame(df_pacs_wm_cmt["ultorg"].unique())
    orgs.columns = ["ultorg"]
    df_lobbying_filt = df_lobbying_filt.merge(orgs, on='ultorg', how='inner')
    df_lobbying_filt["amount"] = df_lobbying_filt["amount"].astype(float)

    #organizations that lobby non-zero amounts and have contributed to the ways and means committee
    df_lobbying_filt = df_lobbying_filt[df_lobbying_filt["amount"] > 0]

    return(df_lobbying_filt.groupby(["registrant","ultorg", "b_id"])["amount"].sum().reset_index())

# %%
df_finance_wm, min_quarter = finance_ways_means(df_cand, df_pacs, ways_and_means_members)
df_finance_wm
# Out:
#                                               ultorg        cid  \
# 211                         Humane Society of the US  N00007727
# 118                           Blue Cross/Blue Shield  N00007727
# 278  National Assn of Insurance & Financial Advisors  N00036018
# 282   National Assn of Real Estate Investment Trusts  N00036018
# 134                       Carpenters & Joiners Union  N00007727
# ..                                               ...        ...
# 209                            Human Rights Campaign  N00036018
# 329                               Planned Parenthood  N00036018
# 328                               Planned Parenthood  N00007727
# 25                     America's Communications Assn  N00036018
# 148                                   Crawford Group  N00036018
#
#           firstlastp  amount
# 211  Earl Blumenauer   17599
# 118  Earl Blumenauer   12500
# 278        Don Beyer   10000
# 282        Don Beyer   10000
# 134  Earl Blumenauer   10000
# ..               ...     ...
# 209        Don Beyer      12
# 329        Don Beyer       8
# 328  Earl Blumenauer       8
# 25         Don Beyer   -1000
# 148        Don Beyer   -2500
#
# [404 rows x 4 columns]

# %%
df_lobbying_wm = lobbying_committee(df_lobbying, df_agency, "002 ", df_finance_wm, min_quarter)
df_lobbying_wm.head()
# Out:
# /var/folders/5c/qtn4glhd0t7819wv3q972_dh0000gn/T/ipykernel_21463/50407524.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_lobbying_filt['quarter'] = pd.to_datetime(df_lobbying_filt['quarter'], errors='coerce').dt.to_period('Q-DEC')
#    registrant      ultorg        b_id     amount
# 0    AES Corp    AES Corp  hr3684-117    20000.0
# 1    AES Corp    AES Corp   s2377-117    20000.0
# 2  Amazon.com  Amazon.com    hr21-117  4950000.0
# 3  Amazon.com  Amazon.com  hr5736-117  4950000.0
# 4  Amazon.com  Amazon.com  hr7900-117  4950000.0

# %%
def create_network(df_finance_wm, df_lobbying_wm, select_n):

    org_cand = df_finance_wm[["ultorg", "firstlastp", "amount"]][:select_n]

    org_reg = df_lobbying_wm.merge(pd.DataFrame(org_cand["ultorg"]), on='ultorg', how='inner')

    #distinguish in house lobbying firms from parent companies
    similar_names = set(org_reg["ultorg"]).intersection(set(org_reg["registrant"]))
    org_reg['registrant'] = org_reg.apply(lambda x: x['registrant'] + ' (IH)' if x['registrant'] in similar_names else x['registrant'], axis=1)
    org_reg = org_reg[["ultorg", "registrant", "amount"]]

    reg_agency = pd.DataFrame(org_reg['registrant'].unique())
    reg_agency["agency"] = "House of Representatives"
    reg_agency.columns = ["registrant", "agency"]

    cand_agency = pd.DataFrame(org_cand["firstlastp"].unique())
    cand_agency["agency"] = "House of Representatives"
    cand_agency.columns = ["firstlastp", "agency"]
    cand_agency = cand_agency[['agency', 'firstlastp']]

    reg_bill = df_lobbying_wm[["registrant", "b_id"]].merge(pd.DataFrame(org_reg["registrant"]), on='registrant', how='inner').drop_duplicates()

    return org_cand, org_reg, reg_agency, cand_agency, reg_bill

# %%
org_cand, org_reg, reg_agency, cand_agency, reg_bill = create_network(df_finance_wm, df_lobbying_wm, 10)

# %%
reg_bill.head()
# Out:
#                             registrant        b_id
# 0                     Avenue Solutions  hr3173-117
# 2                     Avenue Solutions   s3018-117
# 4   Blue Cross/Blue Shield of Michigan  hr7666-117
# 10  Blue Cross/Blue Shield of Michigan  hr7767-117
# 16  Blue Cross/Blue Shield of Michigan  hr7780-117

# %%
org_cand.head()
# Out:
#                                               ultorg       firstlastp  amount
# 211                         Humane Society of the US  Earl Blumenauer   17599
# 118                           Blue Cross/Blue Shield  Earl Blumenauer   12500
# 278  National Assn of Insurance & Financial Advisors        Don Beyer   10000
# 282   National Assn of Real Estate Investment Trusts        Don Beyer   10000
# 134                       Carpenters & Joiners Union  Earl Blumenauer   10000

# %%
org_reg
# Out:
#                              ultorg                            registrant  \
# 0   American Federation of Teachers  American Federation of Teachers (IH)
# 1   American Federation of Teachers  American Federation of Teachers (IH)
# 2   American Federation of Teachers  American Federation of Teachers (IH)
# 3   American Federation of Teachers  American Federation of Teachers (IH)
# 4   American Federation of Teachers  American Federation of Teachers (IH)
# 5   American Federation of Teachers  American Federation of Teachers (IH)
# 6            Blue Cross/Blue Shield                      Avenue Solutions
# 7            Blue Cross/Blue Shield                      Avenue Solutions
# 8            Blue Cross/Blue Shield    Blue Cross/Blue Shield of Michigan
# 9            Blue Cross/Blue Shield    Blue Cross/Blue Shield of Michigan
# 10           Blue Cross/Blue Shield    Blue Cross/Blue Shield of Michigan
# 11           Blue Cross/Blue Shield    Blue Cross/Blue Shield of Michigan
# 12           Blue Cross/Blue Shield    Blue Cross/Blue Shield of Michigan
# 13           Blue Cross/Blue Shield    Blue Cross/Blue Shield of Michigan
#
#       amount
# 0   370000.0
# 1   370000.0
# 2   370000.0
# 3   370000.0
# 4   370000.0
# 5   370000.0
# 6    80000.0
# 7    80000.0
# 8   492220.0
# 9   246110.0
# 10  246110.0
# 11  246110.0
# 12  246110.0
# 13  246110.0

# %%
reg_agency.head()
# Out:
#                              registrant                    agency
# 0  American Federation of Teachers (IH)  House of Representatives
# 1                      Avenue Solutions  House of Representatives
# 2    Blue Cross/Blue Shield of Michigan  House of Representatives

# %%
cand_agency.head()
# Out:
#                      agency       firstlastp
# 0  House of Representatives  Earl Blumenauer
# 1  House of Representatives        Don Beyer

# %%
import matplotlib.pyplot as plt

def viz_graph(org_cand, org_reg, reg_agency, cand_agency, reg_bill):
    G = nx.Graph()
    G.add_weighted_edges_from(org_cand.values)
    G.add_weighted_edges_from(org_reg.values)
    # G.add_edges_from(reg_agency.values)
    # G.add_edges_from(cand_agency.values)
    G.add_edges_from(reg_bill.values)
    # Add node attributes for type
    for node in org_cand['ultorg'].unique():
        G.nodes[node]['type'] = 'organization'
    for node in org_cand['firstlastp'].unique():
        G.nodes[node]['type'] = 'candidate'
    for node in org_reg['registrant'].unique():
        G.nodes[node]['type'] = 'registrant'
    # for node in reg_agency['agency'].unique():
    #     G.nodes[node]['type'] = 'agency'
    for node in reg_bill['b_id'].unique():
        G.nodes[node]['type'] = 'bill'


    node_colors = []
    for node in G.nodes(data=True):
        if node[1]['type'] == 'organization':
            node_colors.append('lightblue')
        # elif node[1]['type'] == 'agency':
        #     node_colors.append('lightgreen')
        elif node[1]['type'] == 'candidate':
            node_colors.append('lightcoral')
        elif node[1]['type'] == 'registrant':
            node_colors.append('red')
        elif node[1]['type'] == 'bill':
            node_colors.append('yellow')
        else:
            None

    node_sizes = {'organization': 200, 'agency': 200, 'candidate': 200, 'registrant': 100, 'bill': 100}
    node_size_list = [node_sizes[G.nodes[node]['type']] for node in G.nodes()]

    """"
    #pos = nx.shell_layout(G)
    pos = nx.spring_layout(G, seed = 100)
    fig, ax = plt.subplots()
    node_sizes = {'organization': 1000, 'agency': 2000, 'candidate': 2000, 'registrant': 200}
    node_size_list = [node_sizes[G.nodes[node]['type']] for node in G.nodes()]
    nx.draw(G, pos, with_labels=True, labels=nx.get_node_attributes(G, 'label'), node_size=node_size_list, node_color=node_colors, font_size=5, font_weight='bold', ax=ax)
    #nx.draw(G, pos, node_size=node_size_list, node_color=node_colors, font_weight='bold', ax=ax)
    plt.show()
    """

    plt.figure(figsize=(12, 12))
    #edge_widths = [G[u][v]['weight'] / 1000 for u, v in G.edges()]
    pos = nx.multipartite_layout(G, subset_key="type")
    nx.draw(G, pos, with_labels=True, node_size=node_size_list, node_color=node_colors, font_size=8, font_weight='bold')
    plt.show()

# %%
def create_network2(df_finance_wm, df_lobbying_wm, select_n):

    org_cand = df_finance_wm[["ultorg", "firstlastp", "amount"]][:select_n]

    org_reg = df_lobbying_wm.merge(org_cand, on='ultorg', how='inner', suffixes=('_lobby', '_fin'))
    """
    #distinguish in house lobbying firms from parent companies
    similar_names = set(org_reg["ultorg"]).intersection(set(org_reg["registrant"]))
    org_reg['registrant'] = org_reg.apply(lambda x: x['registrant'] + ' (IH)' if x['registrant'] in similar_names else x['registrant'], axis=1)
    org_reg = org_reg[["ultorg", "registrant", "amount"]]

    reg_agency = pd.DataFrame(org_reg['registrant'].unique())
    reg_agency["agency"] = "House of Representatives"
    reg_agency.columns = ["registrant", "agency"]

    cand_agency = pd.DataFrame(org_cand["firstlastp"].unique())
    cand_agency["agency"] = "House of Representatives"
    cand_agency.columns = ["firstlastp", "agency"]
    cand_agency = cand_agency[['agency', 'firstlastp']]

    return org_cand, org_reg, reg_agency, cand_agency
"""
    return org_reg

# %%
create_network2(df_finance_wm, df_lobbying_wm, 10)
# Out:
#                             registrant                           ultorg  \
# 0      American Federation of Teachers  American Federation of Teachers
# 1      American Federation of Teachers  American Federation of Teachers
# 2      American Federation of Teachers  American Federation of Teachers
# 3      American Federation of Teachers  American Federation of Teachers
# 4      American Federation of Teachers  American Federation of Teachers
# 5      American Federation of Teachers  American Federation of Teachers
# 6                     Avenue Solutions           Blue Cross/Blue Shield
# 7                     Avenue Solutions           Blue Cross/Blue Shield
# 8   Blue Cross/Blue Shield of Michigan           Blue Cross/Blue Shield
# 9   Blue Cross/Blue Shield of Michigan           Blue Cross/Blue Shield
# 10  Blue Cross/Blue Shield of Michigan           Blue Cross/Blue Shield
# 11  Blue Cross/Blue Shield of Michigan           Blue Cross/Blue Shield
# 12  Blue Cross/Blue Shield of Michigan           Blue Cross/Blue Shield
# 13  Blue Cross/Blue Shield of Michigan           Blue Cross/Blue Shield
#
#           b_id  amount_lobby       firstlastp  amount_fin
# 0   hr3115-117      370000.0        Don Beyer       10000
# 1   hr3115-117      370000.0  Earl Blumenauer       10000
# 2   hr8450-117      370000.0        Don Beyer       10000
# 3   hr8450-117      370000.0  Earl Blumenauer       10000
# 4    s1530-117      370000.0        Don Beyer       10000
# 5    s1530-117      370000.0  Earl Blumenauer       10000
# 6   hr3173-117       80000.0  Earl Blumenauer       12500
# 7    s3018-117       80000.0  Earl Blumenauer       12500
# 8   hr7666-117      492220.0  Earl Blumenauer       12500
# 9   hr7767-117      246110.0  Earl Blumenauer       12500
# 10  hr7780-117      246110.0  Earl Blumenauer       12500
# 11   hr959-117      246110.0  Earl Blumenauer       12500
# 12    s346-117      246110.0  Earl Blumenauer       12500
# 13   s4804-117      246110.0  Earl Blumenauer       12500

# %%
wm_repub_fin, min_quarter = finance_ways_means(df_cand, df_pacs, wm_repub['firstlastp'])

# %%
df_lobbying_wm_repub = lobbying_committee(df_lobbying, df_agency, "002 ", wm_repub_fin, min_quarter)
# Out:
# /var/folders/5c/qtn4glhd0t7819wv3q972_dh0000gn/T/ipykernel_21463/50407524.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_lobbying_filt['quarter'] = pd.to_datetime(df_lobbying_filt['quarter'], errors='coerce').dt.to_period('Q-DEC')

# %%
df_lobbying_wm_repub.head()
# Out:
#                    registrant                      ultorg        b_id   amount
# 0                    AES Corp                    AES Corp  hr3684-117  20000.0
# 1                    AES Corp                    AES Corp   s2377-117  20000.0
# 2  Alabama Farmers Federation  Alabama Farmers Federation  hr1020-118  60000.0
# 3  Alabama Farmers Federation  Alabama Farmers Federation   hr714-118  60000.0
# 4  Alabama Farmers Federation  Alabama Farmers Federation  hr7606-117  50000.0

# %%
org_cand, org_reg, reg_agency, cand_agency, reg_bill = create_network(wm_repub_fin, df_lobbying_wm_repub, 20)

# %%
viz_graph(org_cand, org_reg, reg_agency, cand_agency, reg_bill)

# %%
org_cand.head()
# Out:
#                                ultorg        firstlastp   amount
# 2973               House Majority PAC  David Schweikert  1720471
# 574     American Dream Federal Action  David Schweikert   500479
# 1835    Congressional Leadership Fund  David Schweikert   460635
# 3567  Make America Great Again Action        Mike Carey   417132
# 1043         Americans for Prosperity  David Schweikert   330977

# %%
org_reg.head()
# Out:
#                       ultorg                   registrant   amount
# 0  National Assn of Realtors  California Assn of Realtors  51888.0
# 1  National Assn of Realtors  California Assn of Realtors  51888.0
# 2  National Assn of Realtors  California Assn of Realtors  51888.0
# 3  National Assn of Realtors  California Assn of Realtors  51888.0
# 4  National Assn of Realtors  California Assn of Realtors  51888.0

# %%
reg_agency.head()
# Out:
#                        registrant                    agency
# 0     California Assn of Realtors  House of Representatives
# 1  National Assn of Realtors (IH)  House of Representatives

# %%
cand_agency.head()
# Out:
#                      agency         firstlastp
# 0  House of Representatives   David Schweikert
# 1  House of Representatives         Mike Carey
# 2  House of Representatives     Michelle Steel
# 3  House of Representatives  Brian Fitzpatrick
# 4  House of Representatives       Darin LaHood

# %%
reg_bill.head()
# Out:
#                      registrant        b_id
# 0   California Assn of Realtors  hr1319-117
# 19  California Assn of Realtors  hr1836-117
# 38  California Assn of Realtors  hr2126-117
# 57  California Assn of Realtors  hr2143-117
# 76  California Assn of Realtors  hr3684-117
