# %%
import pandas as pd
import numpy as np

# %%
# Blank excel column
columns_indivs = ['cycle', 'fectransid', 'contribid', 'contrib', 'recipid', 'orgname',
                   'ultorg', 'realcode', 'date', 'amount', 'street', 'city', 'state', 'zip',
                   'recipcode', 'type', 'cmteid', 'otherid', 'gender', 'microfilm',
                   'occupation', 'employer', 'source']
columns_indivs = dict(enumerate(columns_indivs))

# %%
df = pd.read_csv('../../data/open_secrets/indivs_N00000362_20.csv', header=None, skiprows=1)
df = df.rename(columns=columns_indivs)

# %%
# Get rid of the pipes on both sides of the data.
df = df.map(lambda x: x.replace('|', '') if type(x) == str else x)

# Other cleanup.
df['cycle'] = df['cycle'].apply(lambda x: int(x))
df['fectransid'] = df['fectransid'].apply(lambda x: int(x))
df['date'] = df['date'].apply(lambda x: x[:10])
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
df['amount'] = df['amount'].apply(lambda x: int(x))
df['zip'] = df['zip'].apply(lambda x: int(x))

# %%
pd.options.display.max_columns = None
df
# Out:
#       cycle           fectransid    contribid                contrib  \
# 0      2020  4032420201713158048  i3003425569      SPERLING, MICHAEL
# 1      2020  4040220201721116424  h1001289155        CHOQUETTE, PAUL
# 2      2020  4040220201720086172  m0001319780         BRAMZON, DAVID
# 3      2020  4040220201724134365  c0070444420        GIANCOLA, LOUIS
# 4      2020  4040220201727072484  p0005312808      KORNFELD, RICHARD
# ...     ...                  ...          ...                    ...
# 2306   2020  4051420201752282628  j1002280440       STURTEVANT, MARY
# 2307   2020  4051420201752604217  e1110791881            TING, DAVID
# 2308   2020  4030220201213570420  h1001143082          MILLER, MYRON
# 2309   2020  4020320212016074888  n0001155310            ALMON, DAWN
# 2310   2020  4030220201215122929  j1002510624  VAN GEERTRUYDEN, YANN
#
#         recipid             orgname ultorg realcode       date  amount  \
# 0     N00000362  [24T Contribution]    NaN    Z9500 2020-01-17    2000
# 1     N00000362  [24T Contribution]    NaN    Z9500 2020-02-07    1500
# 2     N00000362  [24T Contribution]    NaN    Z9500 2020-02-21     250
# 3     N00000362  [24T Contribution]    NaN    Z9500 2020-02-12    1000
# 4     N00000362  [24T Contribution]    NaN    Z9500 2020-02-14    1000
# ...         ...                 ...    ...      ...        ...     ...
# 2306  N00000362  [24T Contribution]    NaN    Z9500 2020-03-12    2000
# 2307  N00000362  [24T Contribution]    NaN    Z9500 2020-03-10    1000
# 2308  N00000362  [24T Contribution]    NaN    Z9500 2019-10-08     500
# 2309  N00000362  [24T Contribution]    NaN    Z9500 2020-10-13      25
# 2310  N00000362  [24T Contribution]    NaN    Z9500 2019-10-09    1400
#
#       street        city state    zip recipcode type     cmteid    otherid  \
# 0        NaN      BOSTON    MA   2116        DW  24T  C00401224  C00238907
# 1        NaN     WARWICK    RI   2818        DW  24T  C00401224  C00238907
# 2        NaN   SAN DIEGO    CA  92101        DW  24T  C00401224  C00238907
# 3        NaN  PROVIDENCE    RI   2906        DW  24T  C00401224  C00238907
# 4        NaN    LA JOLLA    CA  92037        DW  24T  C00401224  C00238907
# ...      ...         ...   ...    ...       ...  ...        ...        ...
# 2306     NaN   ARLINGTON    VA  22207        DW  24T  C00401224  C00238907
# 2307     NaN      BOSTON    MA   2116        DW  24T  C00401224  C00238907
# 2308     NaN      DENVER    CO  80222        DW  24T  C00401224  C00238907
# 2309     NaN  PALM COAST    FL  32137        DW  24T  C00401224  C00238907
# 2310     NaN  WASHINGTON    DC  20006        DW  24T  C00401224  C00238907
#
#      gender           microfilm             occupation  \
# 0         M  202002219201582298               INVESTOR
# 1         M  202003209210675429          VICE CHAIRMAN
# 2         M  202003209210502345  REAL ESTATE DEVELOPER
# 3         M  202003209211156076           NOT EMPLOYED
# 4         M  202003209211657449                    CEO
# ...     ...                 ...                    ...
# 2306      F  202004219230182139         VICE PRESIDENT
# 2307      M  202004219230238335         ADMINISTRATION
# 2308      M  202001299182307009                    NaN
# 2309      F  202012179387416303           NOT EMPLOYED
# 2310      U  202001299174998026               ATTORNEY
#
#                     employer source
# 0                    BAUPOST  Rept
# 1              GILBANE, INC.  Rept
# 2                       SELF  Rept
# 3               NOT EMPLOYED  Rept
# 4          KITU SYSTEMS, INC  Rept
# ...                      ...    ...
# 2306         LOCKHEED MARTIN  Rept
# 2307  MUGAR ENTERPRISES INC.  Rept
# 2308                     NaN  Rept
# 2309            NOT EMPLOYED  Rept
# 2310     GOULSTON AND STORRS  Rept
#
# [2311 rows x 23 columns]
