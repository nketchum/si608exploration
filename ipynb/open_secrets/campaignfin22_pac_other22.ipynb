# %%
import pandas as pd
import numpy as np

# %%
# Dataset description:
# https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20PAC%20to%20PAC%20Data.htm
columns_campfin22_pac_other22 = ['cycle', 'fecrecno', 'filerid', 'donorcmte', 'contriblendtrans', 'city', 'state', 
                            'zip', 'fecoccemp', 'primcode', 'date', 'amount', 'recipid', 'party', 'otherid',
                            'recipcode', 'recipprimcode', 'amend', 'report', 'pg', 'microfilm', 'type',
                            'realcode', 'source']
columns_campfin22_pac_other22 = dict(enumerate(columns_campfin22_pac_other22))

# %%
df = pd.read_csv('../../data/open_secrets/CampaignFin22/pac_other22.csv', on_bad_lines='skip', sep=',', header=None, na_values=['N/A', 'NA'])
df = df.rename(columns=columns_campfin22_pac_other22)
# Out:
# /var/folders/rm/kxyn59hn41j35zkp54p83xp40000gn/T/ipykernel_86991/1431495892.py:1: DtypeWarning: Columns (8,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../data/open_secrets/CampaignFin22/pac_other22.csv', on_bad_lines='skip', sep=',', header=None, na_values=['N/A', 'NA'])

# %%
# Get rid of the pipes on both sides of the data.
df = df.applymap(lambda x: x.replace('|', '') if type(x) == str else x)

# Other cleanup.
df['cycle'] = df['cycle'].apply(lambda x: int(x))
df['fecrecno'] = df['fecrecno'].apply(lambda x: int(x))

df['date'] = pd.to_datetime(df['date'], format='%m/%d/%Y', errors='coerce')
df = df.dropna(subset=['date'])

df['microfilm'] = df['microfilm'].fillna(0)
df['microfilm'] = df['microfilm'].apply(lambda x: 0 if x == '' else int(x))

# %%
pd.options.display.max_columns = None
df
# Out:
#          cycle             fecrecno    filerid                  donorcmte  \
# 0         2022  1011320230265253021  C00032979            Teamsters Union
# 1         2022  1011320230265254787  C00032979            Teamsters Union
# 2         2022  1011320230265254797  C00032979            Teamsters Union
# 3         2022  1011320230265254799  C00032979            Teamsters Union
# 4         2022  1011320230265254826  C00032979            Teamsters Union
# ...        ...                  ...        ...                        ...
# 1017517   2022  4123120221645576752  C00575126  Jamie Raskin for Congress
# 1017518   2022  4123120221645576759  C00575126  Jamie Raskin for Congress
# 1017519   2022  4123120221645576813  C00727529         Mrvan for Congress
# 1017520   2022  4123120221645577062  C00727529         Mrvan for Congress
# 1017521   2022  4123120221645577072  C00727529         Mrvan for Congress
#
#                                           contriblendtrans          city  \
# 0                                    BOHANNAN VICTORY FUND     IOWA CITY
# 1                                     WARNOCK VICTORY FUND    WASHINGTON
# 2                                           BLUE POWER PAC   COLLINSWOOD
# 3                                         COMMONWEALTH PAC    MERRIFIELD
# 4                       RHODE ISLAND DEMOCRATIC STATE CMTE    PROVIDENCE
# ...                                                    ...           ...
# 1017517  GIVING WILLINGLY EMPOWERING NATIONALLY (GWEN) PAC    WASHINGTON
# 1017518                                 RILEY VICTORY FUND    WASHINGTON
# 1017519  INDIANA DEMOCRATIC CONGRESSIONAL VICTORY COMMI...  INDIANAPOLIS
# 1017520                                          SHORE PAC   LONG BRANCH
# 1017521  INDIANA DEMOCRATIC CONGRESSIONAL VICTORY COMMI...  INDIANAPOLIS
#
#         state    zip fecoccemp primcode       date   amount    recipid party  \
# 0          IA  52245       NaN    LT300 2022-11-15  -1000.0  C00811059     D
# 1          DC  20003       NaN    LT300 2022-11-22  15000.0  C00740597     D
# 2          NJ  08108       NaN    LT300 2022-11-03   5000.0  C00575894     D
# 3          VA  22116       NaN    LT300 2022-11-03   5000.0  C00498931     D
# 4          RI  92940       NaN    LT300 2022-11-03   5000.0  C00136200     D
# ...       ...    ...       ...      ...        ...      ...        ...   ...
# 1017517    DC  20033       NaN    Z1200 2022-10-11   1000.0  C00431478     D
# 1017518    DC  20003       NaN    Z1200 2022-10-18   2000.0  C00823724     D
# 1017519    IN  46204       NaN    Z1200 2022-10-17  45000.0  C00108613     D
# 1017520    NJ  07740       NaN    Z1200 2022-11-21   -500.0  C00410308     D
# 1017521    IN  46204       NaN    Z1200 2022-10-28   3500.0  C00108613     D
#
#            otherid recipcode recipprimcode amend report pg  \
# 0        C00811059        DP         Z4200     A    30G  P
# 1        C00740597        DP         Z4200     A    30G  P
# 2        C00575894        PI         J2100     A    30G  P
# 3        C00498931        PI         J2100     A    30G  P
# 4        C00136200        DP         Z5200     A    30G  P
# ...            ...       ...           ...   ...    ... ..
# 1017517  C00431478        PI         J2100     A    12G  P
# 1017518  C00823724        DP         Z4200     A    12G  P
# 1017519  C00108613        DP         Z5200     A    12G  G
# 1017520  C00410308        PI         J2100     A    30G  G
# 1017521  C00108613        DP         Z5200     A    30G  G
#
#                   microfilm type realcode source
# 0        202212089550408190  24K    LT300  PAC
# 1        202212089550408210  24K    LT300  PAC
# 2        202212089550408207  24K    LT300  PAC
# 3        202212089550408208  24K    LT300  PAC
# 4        202212089550408209  24K    LT300  PAC
# ...                     ...  ...      ...    ...
# 1017517  202212299574243030  24K    Z1200  PAC
# 1017518  202212299574243032  24K    Z1200  PAC
# 1017519  202212299574243275  24K    Z1200  PAC
# 1017520  202212299574244193  22Z    Z1200  PAC
# 1017521  202212299574244196  24K    Z1200  PAC
#
# [1014003 rows x 24 columns]
