# %%
import pandas as pd
import numpy as np

# %%
# Dataset description:
# https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20lob_issues.htm
columns_lob_issue = ['si_id', 'uniqid', 'issueid', 'issue', 'specificissue', 5, 6, 7, 8, 9, 10, 'year']
columns_lob_issue = dict(enumerate(columns_lob_issue))

# %%
df = pd.read_csv('../../data/open_secrets/Lobby/lob_issue.csv', on_bad_lines='skip', sep=',', header=None, na_values=['N/A', 'NA'], encoding='ISO-8859-1')
df = df.rename(columns=columns_lob_issue)

# %%
# Get rid of the pipes on both sides of the data.
df = df.applymap(lambda x: x.replace('|', '') if type(x) == str else x)

# Other cleanup.
df['year'] = pd.to_numeric(df['year'], errors='coerce')
df = df.dropna(subset=['year'])
df['year'] = df['year'].astype(int)

# %%
pd.options.display.max_columns = None
df
# Out:
#                                                      si_id  \
# 0                                                  3001624
# 1                                                  3001625
# 2                                                  3001627
# 3                                                  3001628
# 4                                                  3001629
# ...                                                    ...
# 1840733  Issues pertaining to coverage and reimbursemen...
# 1840783                      Malnutrition Quality Measures
# 1840797    Issues related to the HHS Provider Relief Fund.
# 1840806                  -Patient-focused drug development
# 1841019                      Issues related to Section 230
#
#                                                     uniqid  \
# 0                     02e92bd6-0159-495e-9d00-8a490a0be8be
# 1                     02e92bd6-0159-495e-9d00-8a490a0be8be
# 2                     02e92bd6-0159-495e-9d00-8a490a0be8be
# 3                     02e92bd6-0159-495e-9d00-8a490a0be8be
# 4                     02e92bd6-0159-495e-9d00-8a490a0be8be
# ...                                                    ...
# 1840733  Issues related to Part D coverage of generic d...
# 1840783  Medically Tailored Home-Delivered Meals Demons...
# 1840797         Issues related to physician reimbursement.
# 1840806                             CMS patient engagement
# 1841019          Issues related to COVID-19 misinformation
#
#                              issueid  \
# 0                                DIS
# 1                                ENV
# 2                                ROD
# 3                                RRR
# 4                                TAX
# ...                              ...
# 1840733   including Part D redesign.
# 1840783                         2021
# 1840797                         2021
# 1840806                         2021
# 1841019                         2021
#
#                                                      issue  \
# 0                            Disaster & Emergency Planning
# 1                                  Environment & Superfund
# 2                                         Roads & Highways
# 3                                                Railroads
# 4                                                    Taxes
# ...                                                    ...
# 1840733  Issues relating to the impact of prescription ...
# 1840783                                            2909992
# 1840797                                            2910050
# 1840806                                            2910055
# 1841019                                            2910262
#
#                                              specificissue               5  \
# 0        Issues affecting manufacturer of railroad and ...   environmental
# 1        Issues affecting manufacturer of railroad and ...   environmental
# 2        Issues affecting manufacturer of railroad and ...   environmental
# 3        Issues affecting manufacturer of railroad and ...   environmental
# 4        Issues affecting manufacturer of railroad and ...   environmental
# ...                                                    ...             ...
# 1840733                                               2021         2909969
# 1840783               8ca29f24-5514-44cd-a796-75bf72bd654f             BUD
# 1840797               981eb996-be11-4a78-aaa3-a268f146a563             TEC
# 1840806               9b27e5f4-46f2-4a79-8556-b262060299ab             HCR
# 1841019               eaecd200-cb9b-4350-b20a-73ba0916d2c0             LBR
#
#                                             6  \
# 0                              transportation
# 1                              transportation
# 2                              transportation
# 3                              transportation
# 4                              transportation
# ...                                       ...
# 1840733  88bac485-00bb-4915-8ca5-8d0ec589ec28
# 1840783           Fed Budget & Appropriations
# 1840797                    Telecommunications
# 1840806                         Health Issues
# 1841019                                 Labor
#
#                                                          7  \
# 0                                                    trade
# 1                                                    trade
# 2                                                    trade
# 3                                                    trade
# 4                                                    trade
# ...                                                    ...
# 1840733                                                TRD
# 1840783  S. Con Res 14 -FY 22 Budget Reconciliation Act...
# 1840797                          Telecommunications policy
# 1840806                      Build Back Better Legislation
# 1841019                              Antitrust & Workplace
#
#                                                     8  \
# 0                                               labor
# 1                                               labor
# 2                                               labor
# 3                                               labor
# 4                                               labor
# ...                                               ...
# 1840733                                         Trade
# 1840783   penalties for employers violating labor law
# 1840797                        general appropriations
# 1840806                     Heroes Act Implementation
# 1841019   Issues related to FTC enforcement authority
#
#                                                          9  \
# 0                                                 shipping
# 1                                                 shipping
# 2                                                 shipping
# 3                                                 shipping
# 4                                                 shipping
# ...                                                    ...
# 1840733                    Issues related to Buy American.
# 1840783                   tax deductibility for union dues
# 1840797                           Emergency Communications
# 1840806                                   Surprise Billing
# 1841019  Issues related to competition legislation; H.R...
#
#                                                         10     year
# 0                        disaster planning and tax issues.     2022
# 1                        disaster planning and tax issues.     2022
# 2                        disaster planning and tax issues.     2022
# 3                        disaster planning and tax issues.     2022
# 4                        disaster planning and tax issues.     2022
# ...                                                    ...      ...
# 1840733                                               2021  2909970
# 1840783   and ensuring that prescription drug negotiate...     2021
# 1840797                                               2021  2910051
# 1840806                     Hospital and Healthcare Policy     2021
# 1841019                                               2021  2910263
#
# [56975 rows x 12 columns]
