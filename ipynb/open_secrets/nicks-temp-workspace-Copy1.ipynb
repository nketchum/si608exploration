# %% [markdown]
# # SI 608 Project – Workspace #
# #### General scratchpad workspace that preloads all the dataframes. ####
# See <code>./modules</code> to review how libraries are installed and imported, as well as where the data is loaded, cleaned, and formatted. This is only here as a helpful tool, make a copy and do whatever you'd like. Or don't use this at all if that's preferable.
#
# [OpenSecrets Data Dictionary Index](../../docs/open_source_data_dictionary.md)
# <br><small><em>(View the index with markdown preview)</em></small>

# %% [markdown]
# ### Initialize
# Init file contains helper functions used throughout the project.

# %%
# %run modules/init.ipynb
# Out:
# Initializing project...
# pandas is already installed.
# matplotlib is already installed.
# networkx is already installed.
# numpy is already installed.
# ...initialization complete.

# %% [markdown]
# #### Load datasets ####
#
# This module provides a single function for all of the *contribution* data from OpenSecrets.

# %%
# %run modules/data.ipynb
# Out:
# Loading data module...
# ...data module loaded.

# %%
# OpenSecrets Data Definition: 527 Committees
# https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20527%20Cmtes.htm
columns_cmtes527 = ['cycle', 'rpt', 'ein', 'crp527name', 'affiliate', 'ultorg', 
                    'recipcode', 'cmteid', 'cid', 'eccmteid', 'party', 
                    'primcode', 'source', 'ffreq', 'ctype', 'csource', 'viewpt',
                    'comments', 'state']

df_cmtes527 = create_dataframe('../../data/open_secrets/527/cmtes527.csv', columns_cmtes527)
# Out:
# Creating cmtes527 dataframe...
# cmtes527 dataframe created...

# %%
df_cmtes527.head()
# Out:
#    cycle_cmtes527 rpt_cmtes527 ein_cmtes527  \
# 0            2002         Q302    861006189
# 1            2008         Q308    262108560
# 2            2000         Q400    912101097
# 3            2012         Q412    522257109
# 4            2008         Q407    900049259
#
#                                 crp527name_cmtes527 affiliate_cmtes527  \
# 0                         American Electronics Assn
# 1          California 2008 GOP Delegation Corporate
# 2            Alabama League of Environmental Action
# 3   International Brotherhood of Electrical Workers
# 4  Pacific Northwest Regional Council of Carpenters
#
#                                    ultorg_cmtes527 recipcode_cmtes527  \
# 0                        American Electronics Assn                 PB
# 1                   California 2008 GOP Delegation                 RP
# 2           Alabama League of Environmental Action                 PI
# 3  International Brotherhood of Electrical Workers                 PL
# 4                       Carpenters & Joiners Union                 PL
#
#   cmteid_cmtes527 cid_cmtes527 eccmteid_cmtes527 party_cmtes527  \
# 0                                                           NaN
# 1                                                             R
# 2                                                           NaN
# 3       C00027342
# 4       C00001016                      C70004205
#
#   primcode_cmtes527 source_cmtes527 ffreq_cmtes527 ctype_cmtes527  \
# 0             C5000           WebPN              Q              F
# 1             Z5100            Name              Q              F
# 2             JE300            Name              Q              S
# 3             LC150             PAC              Q              F
# 4             LB100             PAC              Q              F
#
#   csource_cmtes527 viewpt_cmtes527 comments_cmtes527 state_cmtes527
# 0              NaN               N                               AZ
# 1                                C                               CA
# 2             Name               L                               AL
# 3             Name               L                               DC
# 4            Expen               L                               WA

# %%
# OpenSecrets Data Dictionary 527 Expenditure Data - from IRS Form 8872B
# https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20527%20Expenditures.htm
columns_expends527 = ['rpt', 'formid', 'schbid', 'orgname', 'ein', 'recipient', 
                    'recipientcrp', 'amount', 'date', 'expcode', 'source', 
                    'purpose', 'addr1', 'addr2', 'city', 'state', 'zip',
                    'employer', 'occupation']

df_expends527 = create_dataframe('../../data/open_secrets/527/expends527.csv', columns_expends527)
# Out:
# Creating expends527 dataframe...
# expends527 dataframe created...

# %%
df_expends527.head()
# Out:
#   rpt_expends527  formid_expends527 schbid_expends527  \
# 0           Q210            9595787           2016057
# 1           Q210            9595787           2016059
# 2           Q210            9595791           2016223
# 3           Q210            9595791           2016225
# 4           Q210            9595791           2016228
#
#                  orgname_expends527 ein_expends527 recipient_expends527  \
# 0  Republican State Leadership Cmte      050532524              VERIZON
# 1  Republican State Leadership Cmte      050532524     VERIZON WIRELESS
# 2                             GOPAC      521237780                  ADP
# 3                             GOPAC      521237780                  ADP
# 4                             GOPAC      521237780     AMERICAN EXPRESS
#
#          recipientcrp_expends527  amount_expends527 date_expends527  \
# 0         Verizon Communications                125      2010-04-16
# 1               Verizon Wireless                141      2010-04-09
# 2  Automatic Data Processing Inc                414      2010-04-09
# 3  Automatic Data Processing Inc                 78      2010-04-23
# 4               American Express                  1      2010-04-26
#
#   expcode_expends527 source_expends527                 purpose_expends527  \
# 0                A70              @new                          TELEPHONE
# 1                A70              @new                         CELL PHONE
# 2                W10              @new                      PAYROLL TAXES
# 3                W10              @new                   PAYROLL SERVICES
# 4                U00             tempU  AMEX PYMT $6634.00 DETAIL FOLLOWS
#
#          addr1_expends527 addr2_expends527 city_expends527 state_expends527  \
# 0           PO BOX 660720                           DALLAS               TX
# 1            PO BOX 25505                    LEHIGH VALLEY               PA
# 2  8094 SAND PIPER CIRCLE                      WHITE MARSH               MD
# 3  8094 SAND PIPER CIRCLE                      WHITE MARSH               MD
# 4           P.O. BOX 1270                           NEWARK               NJ
#
#    zip_expends527 employer_expends527 occupation_expends527
# 0           75266                  NA                    NA
# 1           18002                  NA                    NA
# 2           21236                  NA                    NA
# 3           21236                  NA                    NA
# 4            7101                  NA                    NA

# %%
# OpenSecrets Data Dictionary 527 Contribution Data - from IRS Form 8872A
# https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20527%20Receipts.htm
columns_rcpts527 = ['id', 'rpt', 'formid', 'schaid', 'contribid', 'contrib', 
                    'amount', 'date', 'orgname', 'ultorg', 'realcode', 
                    'recipid', 'recipcode', 'party', 'recipient', 'city', 'state',
                    'zip', 'zip4', 'pmsa', 'employer', 'occupation', 'ytd', 'gender', 'source']

df_rcpts527 = create_dataframe('../../data/open_secrets/527/rcpts527.csv', columns_rcpts527)
# Out:
# Creating rcpts527 dataframe...
# rcpts527 dataframe created...

# %%
df_rcpts527.head()
# Out:
#    id_rcpts527 rpt_rcpts527  formid_rcpts527  schaid_rcpts527  \
# 0          981         Q210          9595837          2017490
# 1          982         Q210          9595837          2017492
# 2          983         Q210          9595837          2017387
# 3          984         Q210          9595837          2017390
# 4          985         Q210          9595837          2017393
#
#   contribid_rcpts527            contrib_rcpts527  amount_rcpts527  \
# 0                        WEST LA DEMOCRATIC CLUB                1
# 1                     WINOGRAD FOR CONGRESS 2010              259
# 2                                 FDL ACTION PAC                4
# 3                                   FRANKEN MVPS              190
# 4                        FRIENDS OF BRENT BARTON               49
#
#   date_rcpts527            orgname_rcpts527 ultorg_rcpts527 realcode_rcpts527  \
# 0    2010-04-18     West La Democratic Club                             Z9600
# 1    2010-04-18  Winograd For Congress 2010                             Z9600
# 2    2010-04-18              Fdl Action Pac                             Z9600
# 3    2010-04-18                Franken Mvps                             Z9600
# 4    2010-04-18     Friends Of Brent Barton                             Z9600
#
#   recipid_rcpts527 recipcode_rcpts527 party_rcpts527  \
# 0        270160261                 PI
# 1        270160261                 PI
# 2        270160261                 PI
# 3        270160261                 PI
# 4        270160261                 PI
#
#            recipient_rcpts527 city_rcpts527 state_rcpts527  zip_rcpts527  \
# 0  ActBlue Technical Services       BURBANK             CA         91502
# 1  ActBlue Technical Services       BURBANK             CA         91502
# 2  ActBlue Technical Services    WASHINGTON             DC         20016
# 3  ActBlue Technical Services   MINNEAPOLIS             MN         55458
# 4  ActBlue Technical Services      PORTLAND             OR         97214
#
#   zip4_rcpts527 pmsa_rcpts527 employer_rcpts527 occupation_rcpts527  \
# 0                        4480                NA                  NA
# 1                        4480                NA                  NA
# 2                        8840                NA                  NA
# 3                        5120                NA                  NA
# 4                        6440                NA                  NA
#
#    ytd_rcpts527 gender_rcpts527 source_rcpts527
# 0           473                            Rept
# 1          1049                            Rept
# 2          1524                            Rept
# 3           662                            Rept
# 4           241                            Rept

# %%
# OpenSecrets Data Definition: Candidates
# https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20Candidates%20Data.htm
columns_cands22 = ['cycle', 'feccandid', 'cid', 'firstlastp', 'party', 'distidrunfor', 
                    'distidcurr', 'currcand', 'cyclecand', 'crpico', 'recipcode', 
                    'nopacs']

df_cands22 = create_dataframe('../../data/open_secrets/CampaignFin22/cands22.csv', columns_cands22)

# Remove party labels from names: '3', 'R', 'D', 'I', 'L', 'U', 'i'
df_cands22['firstlast_cands22'] = df_cands22['firstlastp_cands22'].apply(
    lambda x: x.replace(" (3)", "").replace(" (R)", "").replace(" (D)", "").replace(" (I)", "").replace(" (L)", "").replace(" (U)", "").replace(" (i)", "") if isinstance(x, str) else x
)
# Out:
# Creating cands22 dataframe...
# cands22 dataframe created...

# %%
df_cands22.head()
# Out:
#    cycle_cands22 feccandid_cands22 cid_cands22  firstlastp_cands22  \
# 0           2022         H0AK00105   N00039029     Thomas Lamb (3)
# 1           2022         H0AL01055   N00044245      Jerry Carl (R)
# 2           2022         H0AL01063   N00044288     Wes Lambert (R)
# 3           2022         H0AL01097   N00044750  James Averhart (D)
# 4           2022         H0AL02087   N00030768     Martha Roby (R)
#
#   party_cands22 distidrunfor_cands22 distidcurr_cands22 currcand_cands22  \
# 0             3                 AK01
# 1             R                 AL01               AL01                Y
# 2             R                 AL01
# 3             D                 AL01
# 4             R                 AL02
#
#   cyclecand_cands22 crpico_cands22 recipcode_cands22 nopacs_cands22  \
# 0                                                 3N
# 1                 Y              I                RW
# 2                                                 RN
# 3                                                 DN
# 4                                                 RN
#
#   firstlast_cands22
# 0       Thomas Lamb
# 1        Jerry Carl
# 2       Wes Lambert
# 3    James Averhart
# 4       Martha Roby

# %%
# OpenSecrets Table Definition: Committee table
# https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20for%20Cmtes.htm
columns_cmtes22 = ['cycle', 'cmteid', 'pacshort', 'affiliate', 'ultorg', 'recipid', 
                    'recipcode', 'feccandid', 'party', 'primcode', 'source', 'sensitive',
                    'foreign', 'active']

df_cmtes22 = create_dataframe('../../data/open_secrets/CampaignFin22/cmtes22.csv', columns_cmtes22)
# Out:
# Creating cmtes22 dataframe...
# cmtes22 dataframe created...

# %%
df_cmtes22.head()
# Out:
#    cycle_cmtes22 cmteid_cmtes22  \
# 0           2022      C00000059
# 1           2022      C00000422
# 2           2022      C00000489
# 3           2022      C00000547
# 4           2022      C00000729
#
#                                     pacshort_cmtes22      affiliate_cmtes22  \
# 0                                     Hallmark Cards                    NaN
# 1                              American Medical Assn  American Medical Assn
# 2                                Teamsters Local 886        Teamsters Union
# 3  KANSAS MEDICAL SOCIETY POLITICAL ACTION COMMIT...                    NaN
# 4                               American Dental Assn   American Dental Assn
#
#           ultorg_cmtes22 recipid_cmtes22 recipcode_cmtes22 feccandid_cmtes22  \
# 0         Hallmark Cards       C00000059                PB               NaN
# 1  American Medical Assn       C00000422                PB               NaN
# 2        Teamsters Union       C00000489                PL               NaN
# 3                    NaN       C00000547               NaN               NaN
# 4   American Dental Assn       C00000729                PB               NaN
#
#   party_cmtes22 primcode_cmtes22 source_cmtes22 sensitive_cmtes22  \
# 0           NaN            C1400          WAA21                 Y
# 1           NaN            H1100          WAA21                 n
# 2                          LT300          WAA21                 n
# 3             U              NaN            NaN               NaN
# 4           NaN            H1400          WAA21                 n
#
#    foreign_cmtes22  active_cmtes22
# 0                0               1
# 1                0               1
# 2                0               1
# 3                0               0
# 4                0               1

# %%
# OpenSecrets Data Definition for PAC to PAC Data (Pac_other table)
# https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20PAC%20to%20PAC%20Data.htm
columns_pac_other22 = ['cycle', 'fecrecno', 'filerid', 'donorcmte', 'contriblendtrans', 'city', 'state', 
                            'zip', 'fecoccemp', 'primcode', 'date', 'amount', 'recipid', 'party', 'otherid',
                            'recipcode', 'recipprimcode', 'amend', 'report', 'pg', 'microfilm', 'type',
                            'realcode', 'source']

df_pac_other22 = create_dataframe('../../data/open_secrets/CampaignFin22/pac_other22.csv', columns_pac_other22)
# Out:
# Creating pac_other22 dataframe...
# pac_other22 dataframe created...

# %%
df_pac_other22.head()
# Out:
#    cycle_pac_other22  fecrecno_pac_other22 filerid_pac_other22  \
# 0               2022   1011320230265253021           C00032979
# 1               2022   1011320230265254787           C00032979
# 2               2022   1011320230265254797           C00032979
# 3               2022   1011320230265254799           C00032979
# 4               2022   1011320230265254826           C00032979
#
#   donorcmte_pac_other22        contriblendtrans_pac_other22 city_pac_other22  \
# 0       Teamsters Union               BOHANNAN VICTORY FUND        IOWA CITY
# 1       Teamsters Union                WARNOCK VICTORY FUND       WASHINGTON
# 2       Teamsters Union                      BLUE POWER PAC      COLLINSWOOD
# 3       Teamsters Union                    COMMONWEALTH PAC       MERRIFIELD
# 4       Teamsters Union  RHODE ISLAND DEMOCRATIC STATE CMTE       PROVIDENCE
#
#   state_pac_other22  zip_pac_other22 fecoccemp_pac_other22  \
# 0                IA            52245                   NaN
# 1                DC            20003                   NaN
# 2                NJ             8108                   NaN
# 3                VA            22116                   NaN
# 4                RI            92940                   NaN
#
#   primcode_pac_other22 date_pac_other22  amount_pac_other22  \
# 0                LT300       2022-11-15               -1000
# 1                LT300       2022-11-22               15000
# 2                LT300       2022-11-03                5000
# 3                LT300       2022-11-03                5000
# 4                LT300       2022-11-03                5000
#
#   recipid_pac_other22 party_pac_other22 otherid_pac_other22  \
# 0           C00811059                 D           C00811059
# 1           C00740597                 D           C00740597
# 2           C00575894                 D           C00575894
# 3           C00498931                 D           C00498931
# 4           C00136200                 D           C00136200
#
#   recipcode_pac_other22 recipprimcode_pac_other22 amend_pac_other22  \
# 0                    DP                     Z4200                 A
# 1                    DP                     Z4200                 A
# 2                    PI                     J2100                 A
# 3                    PI                     J2100                 A
# 4                    DP                     Z5200                 A
#
#   report_pac_other22 pg_pac_other22  microfilm_pac_other22 type_pac_other22  \
# 0                30G              P     202212089550408190              24K
# 1                30G              P     202212089550408210              24K
# 2                30G              P     202212089550408207              24K
# 3                30G              P     202212089550408208              24K
# 4                30G              P     202212089550408209              24K
#
#   realcode_pac_other22 source_pac_other22
# 0                LT300              PAC
# 1                LT300              PAC
# 2                LT300              PAC
# 3                LT300              PAC
# 4                LT300              PAC

# %%
# OpenSecrets Data Definition: PAC table (PACs to Candidates)
# https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20for%20PAC%20to%20Cands%20Data.htm
columns_pacs22 = ['cycle', 'fecrecno', 'pacid', 'cid', 'amount', 'date', 'realcode', 
                            'type', 'di', 'feccandid']

df_pacs22 = create_dataframe('../../data/open_secrets/CampaignFin22/pacs22.csv', columns_pacs22)
# Out:
# Creating pacs22 dataframe...
# pacs22 dataframe created...

# %%
df_pacs22.head()
# Out:
#    cycle_pacs22      fecrecno_pacs22 pacid_pacs22 cid_pacs22  amount_pacs22  \
# 0          2022  1011020220264924462    C00406124  N00029513            500
# 1          2022  1011320230265253020    C00032979  N00041569          -2500
# 2          2022  1011320230265254779    C00032979  N00041511          -5000
# 3          2022  1011320230265254798    C00032979  N00035575           5000
# 4          2022  1011320230265254809    C00032979  N00041511           4000
#
#   date_pacs22 realcode_pacs22 type_pacs22 di_pacs22 feccandid_pacs22
# 0  2021-10-18           B4000         24K         D        H8IN07184
# 1  2022-11-21           Z9600         24K         D        H8IL14174
# 2  2022-11-18           Z9600         24K         D        H8MN08043
# 3  2022-11-03           Z9600         24K         D        H4FL15155
# 4  2022-11-03           Z9600         24K         D        H8MN08043

# %%
# OpenSecrets Data Definition: Individual Contribution Data
# https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20for%20Individual%20Contribution%20Data.htm
columns_indivs22 = ['cycle', 'fectransid', 'contribid', 'contrib_last', 'contrib_first', 'recipid', 'orgname', 
                    'ultorg', 'realcode', 'date', 'amount', 'street', 'city', 'state',
                    'zip', 'recipcode', 'type', 'cmteid', 'otherid', 'gender', 'microfilm',
                    'occupation', 'employer', 'source']

# This dataset is huge, and crashes my computer. For now, limiting to 5000000 rows
# until a better way is found to trim off this dataset to only the last cycle or two
df_indivs22 = create_dataframe('../../data/open_secrets/CampaignFin22/indivs22.csv', columns_indivs22, nrows=5000000)
# Out:
# Creating indivs22 dataframe...
# indivs22 dataframe created...

# %%
df_indivs22.head()
# Out:
#    cycle_indivs22  fectransid_indivs22 contribid_indivs22  \
# 0            2022  4061520221505841534       r0014256510
# 1            2022  4061520221505841535       r0015503614
# 2            2022  4061520221505841536       p0003861308
# 3            2022  4061520221505841543       p0003689535
# 4            2022  4061520221505841545       q0002181378
#
#   contrib_last_indivs22 contrib_first_indivs22 recipid_indivs22  \
# 0               DILLARD                 DANIEL        C00000935
# 1                 WHITE                 SCOTTO        C00633404
# 2             DOMINGUEZ                 SALLIE        C00632398
# 3               BRADLEY               JANNETTE        C00678839
# 4                 BHATT                  TANYA        C00580068
#
#      orgname_indivs22 ultorg_indivs22 realcode_indivs22 date_indivs22  \
# 0  [24T Contribution]                             Z9500    2021-08-29
# 1  [24T Contribution]                             Z9500    2021-08-29
# 2  [24T Contribution]                             Z9500    2021-08-29
# 3  [24T Contribution]                             Z9500    2021-08-29
# 4  [24T Contribution]                             Z9500    2021-08-29
#
#    amount_indivs22 street_indivs22 city_indivs22 state_indivs22  zip_indivs22  \
# 0               35                       HIDALGO             TX         78557
# 1               15                       YONKERS             NY         10701
# 2               10                      CAMPBELL             CA         95011
# 3               26                      OAK LAWN             IL         60453
# 4               50                   MIAMI BEACH             FL         33141
#
#   recipcode_indivs22 type_indivs22 cmteid_indivs22 otherid_indivs22  \
# 0                 DP           24T       C00401224        C00000935
# 1                 PI           24T       C00401224        C00633404
# 2                 PI           24T       C00401224        C00632398
# 3                 PI           24T       C00401224        C00678839
# 4                 PI           24T       C00401224        C00580068
#
#   gender_indivs22  microfilm_indivs22 occupation_indivs22  \
# 0               M  202205149504021121        NOT EMPLOYED
# 1               M  202205149507911003        NOT EMPLOYED
# 2               F  202205149504046504          HEALTHCARE
# 3               F  202205149503347140           LIBRARIAN
# 4               F  202205149503225635                MKTG
#
#         employer_indivs22 source_indivs22
# 0            NOT EMPLOYED           Rept
# 1            NOT EMPLOYED           Rept
# 2  MCDONALD FAMILY DENTAL           Rept
# 3          MEDICAL CENTER           Rept
# 4          FRYE FINANCIAL           Rept

# %%
# OpenSecrets Data Dictionary for Expenditure Data - from FEC electronic filings
# https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20Expenditures.htm
columns_expends22 = ['cycle', 'id', 'transid', 'crpfilerid', 
                     'recipcode', 'pacshort', 'crprecipname', 
                     'expcode', 'amount', 'date', 'city', 'state', 
                     'zip', 'cmteid_ef', 'candid', 'type',
                     'descrip', 'pg', 'elecother', 'enttype',
                     'source']

df_expends22 = create_dataframe('../../data/open_secrets/Expend22/expends22.csv', columns_expends22, nrows=1000000)
# Out:
# Creating expends22 dataframe...
# expends22 dataframe created...

# %%
df_expends22.head()
# Out:
#    cycle_expends22  id_expends22 transid_expends22 crpfilerid_expends22  \
# 0             2022             1         500252553            C00143230
# 1             2022             2         500252556            C00143230
# 2             2022             3         500252557            C00143230
# 3             2022             4         500252608            C00143230
# 4             2022             5         500252609            C00143230
#
#   recipcode_expends22              pacshort_expends22 crprecipname_expends22  \
# 0                  DP  New York State Democratic Cmte                ActBlue
# 1                  DP  New York State Democratic Cmte                ActBlue
# 2                  DP  New York State Democratic Cmte                ActBlue
# 3                  DP  New York State Democratic Cmte                ActBlue
# 4                  DP  New York State Democratic Cmte                ActBlue
#
#   expcode_expends22  amount_expends22 date_expends22 city_expends22  \
# 0               F40                 1     2021-05-01     Somerville
# 1               F40                10     2021-05-02     Somerville
# 2               F40                 4     2021-05-02     Somerville
# 3               F40                 6     2021-05-09     Somerville
# 4               F40                 1     2021-05-16     Somerville
#
#   state_expends22  zip_expends22 cmteid_ef_expends22 candid_expends22  \
# 0              MA       21443132
# 1              MA       21443132
# 2              MA       21443132
# 3              MA       21443132
# 4              MA       21443132
#
#    type_expends22           descrip_expends22 pg_expends22  \
# 0             NaN  Credit Card Processing Fee
# 1             NaN  Credit Card Processing Fee
# 2             NaN  Credit Card Processing Fee
# 3             NaN  Credit Card Processing Fee
# 4             NaN  Credit Card Processing Fee
#
#   elecother_expends22 enttype_expends22 source_expends22
# 0                                   ORG            @auto
# 1                                   ORG            @auto
# 2                                   ORG            @auto
# 3                                   ORG            @auto
# 4                                   ORG            @auto

# %%
# OpenSecrets Data Definition for Lobbying Data: Lobby agencies
# https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20lob_agency.htm
columns_lob_agency = ['uniqid', 'agencyid', 'agency']

df_lob_agency = create_dataframe('../../data/open_secrets/Lobby/lob_agency.csv', columns_lob_agency)
# Out:
# Creating lob_agency dataframe...
# lob_agency dataframe created...

# %%
df_lob_agency.head()
# Out:
#                       uniqid_lob_agency  agencyid_lob_agency  \
# 0  BB7367A7-7B60-4DED-AA2D-A94771A9EBE8                    1
# 1  BB7367A7-7B60-4DED-AA2D-A94771A9EBE8                    2
# 2  04366C6F-B0CE-4C28-87BF-EE1CC8A9BB41                    2
# 3  04366C6F-B0CE-4C28-87BF-EE1CC8A9BB41                   34
# 4  04366C6F-B0CE-4C28-87BF-EE1CC8A9BB41                  134
#
#                           agency_lob_agency
# 0                                 US Senate
# 1               US House of Representatives
# 2               US House of Representatives
# 3           Dept of Health & Human Services
# 4  Centers for Disease Control & Prevention

# %%
# OpenSecrets Data Definition for Lobbying Data: Lobby bills
# https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20lob_bills.htm
columns_lob_bills = ['b_id', 'si_id', 'congno', 'bill_name']

df_lob_bills = create_dataframe('../../data/open_secrets/Lobby/lob_bills.csv', columns_lob_bills)
# Out:
# Creating lob_bills dataframe...
# lob_bills dataframe created...

# %%
df_lob_bills.head()
# Out:
#   b_id_lob_bills  si_id_lob_bills  congno_lob_bills bill_name_lob_bills
# 0      s1461-117          2820018               117              S.1461
# 1      hr463-117          2820018               117             H.R.463
# 2       s910-116          2820035               116               S.910
# 3     hr2405-116          2820035               116            H.R.2405
# 4     hr3816-117          2820067               117            H.R.3816

# %%
# OpenSecrets Data Definition for Lobbying Data: Lobby industries
# https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20lob_indus.htm
columns_lob_indus = ['client', 'sub', 'total', 'year', 'catcode']

df_lob_indus = create_dataframe('../../data/open_secrets/Lobby/lob_indus.csv', columns_lob_indus)
# Out:
# Creating lob_indus dataframe...
# lob_indus dataframe created...

# %%
df_lob_indus.head()
# Out:
#                                     client_lob_indus  \
# 0  National Assn for County Community & Econ Develop
# 1                       Fox Valley Technical College
# 2            Employers Cncl on Flexible Compensation
# 3            American Federation of TV/Radio Artists
# 4                     Visiting Nurse Assn of America
#
#                                        sub_lob_indus  total_lob_indus  \
# 0  National Assn for County Community & Econ Develop                0
# 1                       Fox Valley Technical College            80000
# 2            Employers Cncl on Flexible Compensation           580000
# 3            American Federation of TV/Radio Artists            30000
# 4              Visiting Nurse Assn/Manchester & S NH            40000
#
#    year_lob_indus catcode_lob_indus
# 0            1998             X3000
# 1            2015             H5200
# 2            2001             J9000
# 3            2011             LG400
# 4            2005             H3100

# %%
# OpenSecrets Data Definition for Lobbying Data: Lobby issues
# https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20lob_issues.htm
columns_lob_issue = ['si_id', 'uniqid', 'issueid', 'issue', 'specificissue', 5, 6, 7, 8, 9, 10, 'year']

df_lob_issue = create_dataframe('../../data/open_secrets/Lobby/lob_issue.csv', columns_lob_issue)
# Out:
# Creating lob_issue dataframe...
# lob_issue dataframe created...

# %%
df_lob_issue.head()
# Out:
#   si_id_lob_issue                      uniqid_lob_issue issueid_lob_issue  \
# 0         3001624  02e92bd6-0159-495e-9d00-8a490a0be8be               DIS
# 1         3001625  02e92bd6-0159-495e-9d00-8a490a0be8be               ENV
# 2         3001627  02e92bd6-0159-495e-9d00-8a490a0be8be               ROD
# 3         3001628  02e92bd6-0159-495e-9d00-8a490a0be8be               RRR
# 4         3001629  02e92bd6-0159-495e-9d00-8a490a0be8be               TAX
#
#                  issue_lob_issue  \
# 0  Disaster & Emergency Planning
# 1        Environment & Superfund
# 2               Roads & Highways
# 3                      Railroads
# 4                          Taxes
#
#                              specificissue_lob_issue     5_lob_issue  \
# 0  Issues affecting manufacturer of railroad and ...   environmental
# 1  Issues affecting manufacturer of railroad and ...   environmental
# 2  Issues affecting manufacturer of railroad and ...   environmental
# 3  Issues affecting manufacturer of railroad and ...   environmental
# 4  Issues affecting manufacturer of railroad and ...   environmental
#
#        6_lob_issue 7_lob_issue 8_lob_issue 9_lob_issue  \
# 0   transportation       trade       labor    shipping
# 1   transportation       trade       labor    shipping
# 2   transportation       trade       labor    shipping
# 3   transportation       trade       labor    shipping
# 4   transportation       trade       labor    shipping
#
#                          10_lob_issue  year_lob_issue
# 0   disaster planning and tax issues.            2022
# 1   disaster planning and tax issues.            2022
# 2   disaster planning and tax issues.            2022
# 3   disaster planning and tax issues.            2022
# 4   disaster planning and tax issues.            2022

# %%
# OpenSecrets Data Definition for Lobbying Data: Lobby issues (no specific issue)
# https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20lob_issues.htm
columns_lob_issue_no_specific = ['si_id', 'uniqid', 'issueid', 'issue', 'year']

df_lob_issue_no_specific = create_dataframe('../../data/open_secrets/Lobby/lob_issue_NoSpecficIssue.csv', columns_lob_issue_no_specific)
# Out:
# Creating lob_issue_NoSpecficIssue dataframe...
# lob_issue_NoSpecficIssue dataframe created...

# %%
df_lob_issue_no_specific.head()
# Out:
#    si_id_lob_issue_NoSpecficIssue       uniqid_lob_issue_NoSpecficIssue  \
# 0                         3001624  02e92bd6-0159-495e-9d00-8a490a0be8be
# 1                         3001625  02e92bd6-0159-495e-9d00-8a490a0be8be
# 2                         3001627  02e92bd6-0159-495e-9d00-8a490a0be8be
# 3                         3001628  02e92bd6-0159-495e-9d00-8a490a0be8be
# 4                         3001629  02e92bd6-0159-495e-9d00-8a490a0be8be
#
#   issueid_lob_issue_NoSpecficIssue issue_lob_issue_NoSpecficIssue  \
# 0                              DIS  Disaster & Emergency Planning
# 1                              ENV        Environment & Superfund
# 2                              ROD               Roads & Highways
# 3                              RRR                      Railroads
# 4                              TAX                          Taxes
#
#    year_lob_issue_NoSpecficIssue
# 0                           2022
# 1                           2022
# 2                           2022
# 3                           2022
# 4                           2022

# %%
# OpenSecrets Data Definitions for Lobbying Data: Lobbying
# https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20lob_lobbying.htm
columns_lob_lobbying = ['uniqid','registrant_raw','registrant','isfirm','client_raw','client','ultorg','amount',
                        'catcode','source','self','includensfs','use',
                       'ind', 'year', 'type', 'typelong', 'affiliate']

df_lob_lobbying = create_dataframe('../../data/open_secrets/Lobby/lob_lobbying.csv', columns_lob_lobbying, nrows=1000000)
# Out:
# Creating lob_lobbying dataframe...
# lob_lobbying dataframe created...

# %%
df_lob_lobbying.head()
# Out:
#                     uniqid_lob_lobbying           registrant_raw_lob_lobbying  \
# 0  82c5f661-a637-45ad-a3a6-b5ba18cf8962        ASTRAZENECA PHARMACEUTICALS LP
# 1  85b111b1-5d2e-4107-bc24-0921316e29a5            ECHELON GOVERNMENT AFFAIRS
# 2  87822a14-12de-478c-a34d-010fa503e539  WTA -- ADVOCATES FOR RURAL BROADBAND
# 3  87ff989d-9d12-4fef-84ef-ab69cd616894    FINANCIAL EXECUTIVES INTERNATIONAL
# 4  88bac485-00bb-4915-8ca5-8d0ec589ec28         CAPITOL HILL CONSULTING GROUP
#
#                registrant_lob_lobbying isfirm_lob_lobbying  \
# 0          AstraZeneca Pharmaceuticals                 NaN
# 1           Echelon Government Affairs                   y
# 2  Western Telecommunications Alliance                 NaN
# 3   Financial Executives International                 NaN
# 4        Capitol Hill Consulting Group                   y
#
#                              client_raw_lob_lobbying  \
# 0                     ASTRAZENECA PHARMACEUTICALS LP
# 1                                   THE ALBERS GROUP
# 2               WTA -- ADVOCATES FOR RURAL BROADBAND
# 3                 FINANCIAL EXECUTIVES INTERNATIONAL
# 4  ASSOCIATION FOR ACCESSIBLE MEDICINES (FORMERLY...
#
#                     client_lob_lobbying                   ultorg_lob_lobbying  \
# 0           AstraZeneca Pharmaceuticals                       AstraZeneca PLC
# 1                          Albers Group                          Albers Group
# 2   Western Telecommunications Alliance   Western Telecommunications Alliance
# 3    Financial Executives International    Financial Executives International
# 4  Association for Accessible Medicines  Association for Accessible Medicines
#
#    amount_lob_lobbying catcode_lob_lobbying source_lob_lobbying  \
# 0              1370000                H4300               pac
# 1                10000                Y4000
# 2                75000                C4000               pac
# 3                21650                F5000               Hvr06
# 4                40000                H4300               pac
#
#   self_lob_lobbying includensfs_lob_lobbying use_lob_lobbying  \
# 0                 x                                         y
# 1                 n                                         y
# 2                 p                                         y
# 3                 p                                         y
# 4                 i                                         y
#
#   ind_lob_lobbying  year_lob_lobbying type_lob_lobbying  \
# 0                y               2021               q4a
# 1                y               2021                q4
# 2                y               2021                q4
# 3                y               2021                q4
# 4                                2021                q4
#
#       typelong_lob_lobbying affiliate_lob_lobbying
# 0  FOURTH QUARTER AMENDMENT
# 1     FOURTH QUARTER REPORT
# 2     FOURTH QUARTER REPORT
# 3     FOURTH QUARTER REPORT
# 4     FOURTH QUARTER REPORT

# %%
df_lob_lobbying.head()
# Out:
#                     uniqid_lob_lobbying           registrant_raw_lob_lobbying  \
# 0  82c5f661-a637-45ad-a3a6-b5ba18cf8962        ASTRAZENECA PHARMACEUTICALS LP
# 1  85b111b1-5d2e-4107-bc24-0921316e29a5            ECHELON GOVERNMENT AFFAIRS
# 2  87822a14-12de-478c-a34d-010fa503e539  WTA -- ADVOCATES FOR RURAL BROADBAND
# 3  87ff989d-9d12-4fef-84ef-ab69cd616894    FINANCIAL EXECUTIVES INTERNATIONAL
# 4  88bac485-00bb-4915-8ca5-8d0ec589ec28         CAPITOL HILL CONSULTING GROUP
#
#                registrant_lob_lobbying isfirm_lob_lobbying  \
# 0          AstraZeneca Pharmaceuticals                 NaN
# 1           Echelon Government Affairs                   y
# 2  Western Telecommunications Alliance                 NaN
# 3   Financial Executives International                 NaN
# 4        Capitol Hill Consulting Group                   y
#
#                              client_raw_lob_lobbying  \
# 0                     ASTRAZENECA PHARMACEUTICALS LP
# 1                                   THE ALBERS GROUP
# 2               WTA -- ADVOCATES FOR RURAL BROADBAND
# 3                 FINANCIAL EXECUTIVES INTERNATIONAL
# 4  ASSOCIATION FOR ACCESSIBLE MEDICINES (FORMERLY...
#
#                     client_lob_lobbying                   ultorg_lob_lobbying  \
# 0           AstraZeneca Pharmaceuticals                       AstraZeneca PLC
# 1                          Albers Group                          Albers Group
# 2   Western Telecommunications Alliance   Western Telecommunications Alliance
# 3    Financial Executives International    Financial Executives International
# 4  Association for Accessible Medicines  Association for Accessible Medicines
#
#    amount_lob_lobbying catcode_lob_lobbying source_lob_lobbying  \
# 0              1370000                H4300               pac
# 1                10000                Y4000
# 2                75000                C4000               pac
# 3                21650                F5000               Hvr06
# 4                40000                H4300               pac
#
#   self_lob_lobbying includensfs_lob_lobbying use_lob_lobbying  \
# 0                 x                                         y
# 1                 n                                         y
# 2                 p                                         y
# 3                 p                                         y
# 4                 i                                         y
#
#   ind_lob_lobbying  year_lob_lobbying type_lob_lobbying  \
# 0                y               2021               q4a
# 1                y               2021                q4
# 2                y               2021                q4
# 3                y               2021                q4
# 4                                2021                q4
#
#       typelong_lob_lobbying affiliate_lob_lobbying
# 0  FOURTH QUARTER AMENDMENT
# 1     FOURTH QUARTER REPORT
# 2     FOURTH QUARTER REPORT
# 3     FOURTH QUARTER REPORT
# 4     FOURTH QUARTER REPORT

# %%
# OpenSecrets Data Definition for Lobbyists
# https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20lob_lobbyists.htm
columns_lob_lobbyist = ['uniqid', 'lobbyist_lastname_std', 'lobbyist_firstname_std', 'lobbyist_lastname_raw', 
                     'lobbyist_firstname_raw', 'lobbyist_id', 'year', 'officialposition', 'cid', 'formercongmem']

df_lob_lobbyist = create_dataframe('../../data/open_secrets/Lobby/lob_lobbyist.csv', columns_lob_lobbyist, nrows=1000000)
# Out:
# Creating lob_lobbyist dataframe...
# lob_lobbyist dataframe created...

# %%
df_lob_lobbyist.head()
# Out:
#                     uniqid_lob_lobbyist lobbyist_lastname_std_lob_lobbyist  \
# 0  06C29C84-250F-478B-872A-2F647D9DC044                            O'BRIEN
# 1  3A22C685-EC94-46AA-9C45-4AA4A7044C28                              BRAGG
# 2  5CBE61EC-87F1-401E-9D57-620975C9A1F8                           COSTELLO
# 3  8D1DB726-0BE9-46C1-AADE-BE8BCAFF929F                              SMITH
# 4  EF5095CF-92E6-49BE-A40D-35E6464EA394                            SCHMITZ
#
#   lobbyist_firstname_std_lob_lobbyist lobbyist_lastname_raw_lob_lobbyist  \
# 0                     LAWRENCE F. III                            O'Brien
# 1                    PATRICIA DUNMIRE                              Bragg
# 2                                RYAN                           Costello
# 3                            G. WAYNE                              Smith
# 4                             JOHN P.                            Schmitz
#
#   lobbyist_firstname_raw_lob_lobbyist lobbyist_id_lob_lobbyist  \
# 0                      Lawrence F III             Y0000046486L
# 1                    Patricia Dunmire             Y0000020554L
# 2                                Ryan             Y0000027292L
# 3                             G Wayne             Y0000027005L
# 4                              John P             Y0000019948L
#
#    year_lob_lobbyist officialposition_lob_lobbyist cid_lob_lobbyist  \
# 0               2004                           N/A
# 1               2001                           N/A
# 2               2002                           N/A        N00031064
# 3               2004                           N/A
# 4               2002                           N/A
#
#   formercongmem_lob_lobbyist
# 0                          n
# 1                          n
# 2                          y
# 3                          n
# 4                          n

# %%
# OpenSecrets Data Definitions for Lobbying Data: Report types
# No documentation provided on OpenSecrets.com
columns_lob_rpt = ['typelong', 'typeshort']

df_lob_rpt = create_dataframe('../../data/open_secrets/Lobby/lob_rpt.csv', columns_lob_rpt)
# Out:
# Creating lob_rpt dataframe...
# lob_rpt dataframe created...

# %%
df_lob_rpt.head()
# Out:
#                    typelong_lob_rpt typeshort_lob_rpt
# 0                   MID-YEAR REPORT                 m
# 1                MID-YEAR AMENDMENT                ma
# 2            MID-YEAR (NO ACTIVITY)                mn
# 3  MID-YEAR AMENDMENT (NO ACTIVITY)               man
# 4              MID-YEAR TERMINATION                mt

# %%
install_if_needed('xlrd')
import xlrd
# Out:
# xlrd is already installed.

# %%
# Candidate ids
# This dataset is very different, so load it independently.
columns_crp_ids = ['blank_excel_column', 'cid', 'crpname', 'party', 'distidrunfor', 'feccandid'] # Blank excel column is necessary.
columns_crp_ids = dict(enumerate(columns_crp_ids))
df_crp_ids = pd.read_excel('../../data/open_secrets/CRP_IDs.xls', header=None, skiprows=15)
df_crp_ids = df_crp_ids.drop(df_crp_ids.columns[0], axis=1)
df_crp_ids = df_crp_ids.rename(columns=columns_crp_ids)

# %%
df_crp_ids.head()
# Out:
#          cid           crpname party distidrunfor  feccandid
# 0  N00034296      Aalders, Tim     R         UT03  H2UT03280
# 1  N00047923   Aazami, Shervin     D         CA32  H2CA30291
# 2  N00051397    Abahsain, Jill     D         MN07  H2MN07162
# 3  N00051715    Abbott, Martha     3         VTS2  S2VT00359
# 4  N00048268  Abdelhamid, Rana     D         NY12  H2NY12197

# %% [markdown]
# ## Experiments ##

# %% [markdown]
# #### Link lobbies' end ####

# %%
# # See top lobbying by total contributions.
# df_lob_indus_sorted = df_lob_indus.sort_values(by='total_lob_indus', ascending=False)
# df_lob_indus_sorted.head(1)

# %%
# # US Chamber of Commerce is the top lobby.
# df_lob_lobbying[df_lob_lobbying['ultorg_lob_lobbying'] == 'US Chamber of Commerce'].sample(1)

# %%
df_lobbies = pd.merge(df_lob_indus, df_lob_lobbying, left_on='client_lob_indus', right_on='ultorg_lob_lobbying', how='outer')
df_lobbies = df_lobbies[df_lobbies['year_lob_indus'] == df_lobbies['year_lob_lobbying']]

# %%
df_lobbies.sample(5)
# Out:
#                                      client_lob_indus  \
# 9200062                     Florida Sugar Cane League
# 13962991                               Ninesigma Corp
# 4300511                        Blue Cross/Blue Shield
# 18662145            Washington Intern Student Housing
# 12166079  Massachusetts Educational Finance Authority
#
#                                         sub_lob_indus  total_lob_indus  \
# 9200062               Rio Grande Valley Sugar Growers          31000.0
# 13962991                               Ninesigma Corp          40000.0
# 4300511                                  Highmark Inc         530000.0
# 18662145            Washington Intern Student Housing          10000.0
# 12166079  Massachusetts Educational Finance Authority          80000.0
#
#           year_lob_indus catcode_lob_indus  \
# 9200062           2001.0             A1200
# 13962991          2016.0             G5000
# 4300511           2010.0             F3200
# 18662145          2019.0             F4500
# 12166079          2020.0             F1410
#
#                            uniqid_lob_lobbying  \
# 9200062   9579045A-DCCD-4FEE-A350-400B2A7408D1
# 13962991  CBB61435-16E2-4C74-96D9-1073C174ED7C
# 4300511   EF435EA9-51DF-4CC7-97B3-C8A8E06FE8B5
# 18662145  9CE314D6-0D8D-4172-8248-F004136B7193
# 12166079  E689CD1E-66F8-4754-9419-6DCB5A46C67A
#
#                           registrant_raw_lob_lobbying  \
# 9200062                                     PMA GROUP
# 13962991                                    LNE Group
# 4300511   Independence Blue Cross Family of Companies
# 18662145                       Broydrick & Associates
# 12166079                 CHARTWELL STRATEGY GROUP LLC
#
#            registrant_lob_lobbying isfirm_lob_lobbying  \
# 9200062                  PMA Group                   y
# 13962991                 LNE Group                   y
# 4300511    Independence Blue Cross                 NaN
# 18662145         Broydrick & Assoc                   y
# 12166079  Chartwell Strategy Group                   y
#
#                                 client_raw_lob_lobbying  \
# 9200062                       FLORIDA SUGAR CANE LEAGUE
# 13962991                                      NineSigma
# 4300511     INDEPENDENCE BLUE CROSS FAMILY OF COMPANIES
# 18662145                                           WISH
# 12166079  Massachusetts Educational Financing Authority
#
#                                   client_lob_lobbying  \
# 9200062                     Florida Sugar Cane League
# 13962991                               Ninesigma Corp
# 4300511                       Independence Blue Cross
# 18662145            Washington Intern Student Housing
# 12166079  Massachusetts Educational Finance Authority
#
#                                   ultorg_lob_lobbying  amount_lob_lobbying  \
# 9200062                     Florida Sugar Cane League              20000.0
# 13962991                               Ninesigma Corp              20000.0
# 4300511                        Blue Cross/Blue Shield                  0.0
# 18662145            Washington Intern Student Housing                  0.0
# 12166079  Massachusetts Educational Finance Authority              20000.0
#
#          catcode_lob_lobbying source_lob_lobbying self_lob_lobbying  \
# 9200062                 A1200               pac                   i
# 13962991                G5000               webGG                 n
# 4300511                 F3200               pac                   s
# 18662145                F4500               WAA22                 n
# 12166079                F1410               websb                 n
#
#          includensfs_lob_lobbying use_lob_lobbying ind_lob_lobbying  \
# 9200062                                          y
# 13962991                                         y                y
# 4300511                                          n
# 18662145                                         y                y
# 12166079                                         y                y
#
#           year_lob_lobbying type_lob_lobbying  typelong_lob_lobbying  \
# 9200062              2001.0                 m        MID-YEAR REPORT
# 13962991             2016.0                q2  SECOND QUARTER REPORT
# 4300511              2010.0                q4  FOURTH QUARTER REPORT
# 18662145             2019.0                q2  SECOND QUARTER REPORT
# 12166079             2020.0                q2  SECOND QUARTER REPORT
#
#          affiliate_lob_lobbying
# 9200062
# 13962991
# 4300511
# 18662145
# 12166079

# %% [markdown]
# ---

# %% [markdown]
# #### Link candidate's end ####

# %%
df_cands22_clean = df_cands22.copy()
df_cands22_clean = df_cands22_clean.drop(['feccandid_cands22'], axis=1)

# %%
# df_cands22_clean.sample(3)

# %%
df_cmtes22_clean = df_cmtes22.copy()
df_cmtes22_clean = df_cmtes22_clean.drop(['feccandid_cmtes22'], axis=1)

# %%
# df_cmtes22_clean.sample(3)

# %%
df_leadpacs = df_cmtes22_clean[df_cmtes22_clean['recipid_cmtes22'].str.startswith('N')] # Get lead pacs only

# %%
# df_leadpacs.sample(3)

# %%
df_pacs22_clean = df_pacs22.copy()
df_pacs22_clean = df_pacs22_clean.drop(['fecrecno_pacs22', 'feccandid_pacs22'], axis=1)

# %%
# df_pacs22_clean.sample(3)

# %%
df_cands = pd.merge(df_cands22_clean, df_leadpacs, left_on='cid_cands22', right_on='recipid_cmtes22', how='outer')
df_cands = pd.merge(df_cands, df_pacs22_clean, left_on='cid_cands22', right_on='cid_pacs22', how='outer')

# %%
df_cands['cycle_cands22'] = df_cands['cycle_cands22'].astype('Int64')

# %%
# df_cands.sample(3)

# %%
df_cands = df_cands.drop(['cycle_cmtes22', 'recipid_cmtes22', 'recipcode_cmtes22',
                                      'party_cmtes22', 'cycle_pacs22', 'cid_pacs22'], axis=1)

# %%
df_cands.sample(5)
# Out:
#          cycle_cands22 cid_cands22     firstlastp_cands22 party_cands22  \
# 906285            2022   N00046843  Derrick Van Orden (R)             R
# 930134            2022   N00048315        Jen Kiggans (R)             R
# 189597            2022   N00030584        Sarah Palin (R)             R
# 1110829           2022   N00051055      Jennifer Pace (R)             R
# 1015924           2022   N00049229    Herschel Walker (R)             R
#
#         distidrunfor_cands22 distidcurr_cands22 currcand_cands22  \
# 906285                  WI03                                   Y
# 930134                  VA02                                   Y
# 189597                  AK01                                   Y
# 1110829                 IN07
# 1015924                 GAS2                                   Y
#
#         cyclecand_cands22 crpico_cands22 recipcode_cands22 nopacs_cands22  \
# 906285                  Y              O                RW
# 930134                  Y              C                RW
# 189597                  Y              C                RL
# 1110829                 Y              C                RL
# 1015924                 Y              C                RL
#
#         cmteid_cmtes22                                   pacshort_cmtes22  \
# 906285       C00775940                           Van Orden for WI-03 2022
# 930134       C00776120                               Kiggans for Congress
# 189597       C00811323                                   Sarah for Alaska
# 1110829      C00808873  JENNIFER PACE COMMITTEE TO ELECT              ...
# 1015924      C00772962  Walker for GA Senate Republican Nominee Fund 2022
#
#         affiliate_cmtes22                                     ultorg_cmtes22  \
# 906285                NaN                           Van Orden for WI-03 2022
# 930134                NaN                               Kiggans for Congress
# 189597                NaN                                   Sarah for Alaska
# 1110829               NaN                                                NaN
# 1015924               NaN  Walker for GA Senate Republican Nominee Fund 2022
#
#         primcode_cmtes22 source_cmtes22 sensitive_cmtes22  foreign_cmtes22  \
# 906285             Z1100           Rept                 N              0.0
# 930134             Z1100           Rept                 N              0.0
# 189597             Z1100           Rept                 N              0.0
# 1110829              NaN            NaN                 N              0.0
# 1015924            Z1100           Name                 N              0.0
#
#          active_cmtes22 pacid_pacs22  amount_pacs22 date_pacs22  \
# 906285              1.0    C00694323           -1.0  2022-11-28
# 930134              1.0    C00101626         2500.0  2022-08-24
# 189597              1.0    C00694323           -5.0  2022-11-18
# 1110829             0.0          NaN            NaN         NaT
# 1015924             1.0    C00694323          -34.0  2022-10-11
#
#         realcode_pacs22 type_pacs22 di_pacs22
# 906285            Z9600         24K         D
# 930134            F1100         24K         D
# 189597            Z9600         24K         D
# 1110829             NaN         NaN       NaN
# 1015924           Z9600         24K         D

# %% [markdown]
# ---

# %% [markdown]
# #### Link both ends ####

# %%
# Although this df is used for df_leadpacs,df_cands, we filtered
# non-candidate committees out in those two dataframes, so we'll
# return to the full list of committees to get the pac info.
df_cands_or_cmtes = pd.merge(df_cands, df_cmtes22_clean, left_on='pacid_pacs22', right_on='cmteid_cmtes22', how='outer')

# %%
df_cands_or_cmtes = df_cands_or_cmtes.rename(columns=lambda col: col[:-2] + '_cands' if col.endswith('_x') else col)
df_cands_or_cmtes = df_cands_or_cmtes.rename(columns=lambda col: col[:-2] + '_noncands' if col.endswith('_y') else col)

# %%
df_cands_or_indus = pd.merge(df_cands_or_cmtes, df_lob_indus, left_on='ultorg_cmtes22_noncands', right_on='client_lob_indus', how='outer')
df_cands_or_indus = df_cands_or_indus[df_cands_or_indus['cycle_cands22'] == df_cands_or_indus['year_lob_indus']]

# %%
# Remove party labels from names: '3', 'R', 'D', 'I', 'L', 'U', 'i'
# df_cands22_clean['party_cands22'].unique() # List of parties for cell below.
df_cands_or_indus['firstlast_cands22'] = df_cands_or_indus['firstlastp_cands22'].apply(
    lambda x: x.replace(" (3)", "").replace(" (R)", "").replace(" (D)", "").replace(" (I)", "").replace(" (L)", "").replace(" (U)", "").replace(" (i)", "") if isinstance(x, str) else x
)

# %%
# df_cands_or_indus.head()

# %% [markdown]
# ---

# %%
# df_cands_or_indus.head()

# %%
df_cands_and_indus = df_cands_or_indus[df_cands_or_indus['cid_cands22'].notna()]

# %%
# len(df_cands_and_indus)

# %%
# df_cands_and_indus.head()

# %%
# df_cands_and_indus.to_csv('df_cands_and_indus.csv')

# %% [markdown]
# ---

# %% [markdown]
# #### One-by-one tests for the U.S. House Ways & Means committee members ####

# %%
member_name = 'Jodey Arrington'
member_cid = 'N00038285'

# %%
# member_name = 'Don Beyer'
# member_cid = 'N00036018'

# %%
# member_name = 'Earl Blumenauer'
# member_cid = 'N00007727'

# %%
# member_name = 'Vernon Buchanan'
# member_cid = 'N00027626'

# %%
# member_name = 'Mike Kelly'
# member_cid = 'N00031647'

# %%
# Funds according to the aggregate table. (Not accurate)
df_cands_or_indus[df_cands_or_indus['cid_cands22'] == member_cid]['amount_pacs22'].sum()
# Out:
# 1767918.0

# %%
df_cands_or_indus[df_cands_or_indus['firstlast_cands22'] == member_name].to_csv('df_cands_or_indus_' + member_cid + '.csv')

# %%
df_member_by_name = df_cands_or_indus[df_cands_or_indus['firstlast_cands22'] == member_name]

# %%
df_member_by_name.head()
# Out:
#         cycle_cands22 cid_cands22   firstlastp_cands22 party_cands22  \
# 14526            2022   N00038285  Jodey Arrington (R)             R
# 14531            2022   N00038285  Jodey Arrington (R)             R
# 182188           2022   N00038285  Jodey Arrington (R)             R
# 182214           2022   N00038285  Jodey Arrington (R)             R
# 223839           2022   N00038285  Jodey Arrington (R)             R
#
#        distidrunfor_cands22 distidcurr_cands22 currcand_cands22  \
# 14526                  TX19               TX19                Y
# 14531                  TX19               TX19                Y
# 182188                 TX19               TX19                Y
# 182214                 TX19               TX19                Y
# 223839                 TX19               TX19                Y
#
#        cyclecand_cands22 crpico_cands22 recipcode_cands22 nopacs_cands22  \
# 14526                  Y              I                RW
# 14531                  Y              I                RW
# 182188                 Y              I                RW
# 182214                 Y              I                RW
# 223839                 Y              I                RW
#
#        cmteid_cmtes22_cands      pacshort_cmtes22_cands  \
# 14526             C00588657  Texans for Jodey Arrington
# 14531             C00588657  Texans for Jodey Arrington
# 182188            C00588657  Texans for Jodey Arrington
# 182214            C00588657  Texans for Jodey Arrington
# 223839            C00588657  Texans for Jodey Arrington
#
#        affiliate_cmtes22_cands        ultorg_cmtes22_cands  \
# 14526                      NaN  Texans for Jodey Arrington
# 14531                      NaN  Texans for Jodey Arrington
# 182188                     NaN  Texans for Jodey Arrington
# 182214                     NaN  Texans for Jodey Arrington
# 223839                     NaN  Texans for Jodey Arrington
#
#        primcode_cmtes22_cands source_cmtes22_cands sensitive_cmtes22_cands  \
# 14526                   Z1100                 Rept                       N
# 14531                   Z1100                 Rept                       N
# 182188                  Z1100                 Rept                       N
# 182214                  Z1100                 Rept                       N
# 223839                  Z1100                 Rept                       N
#
#         foreign_cmtes22_cands  active_cmtes22_cands pacid_pacs22  \
# 14526                     0.0                   1.0    C00236414
# 14531                     0.0                   1.0    C00236414
# 182188                    0.0                   1.0    C00034157
# 182214                    0.0                   1.0    C00034157
# 223839                    0.0                   1.0    C00109017
#
#         amount_pacs22 date_pacs22 realcode_pacs22 type_pacs22 di_pacs22  \
# 14526          1500.0  2021-04-26           F3100         24K         D
# 14531         -1500.0  2021-04-19           F3100         24K         D
# 182188         2500.0  2022-08-02           F3200         24K         D
# 182214         2500.0  2022-08-19           F3200         24K         D
# 223839         5000.0  2022-01-31           C4100         24K         D
#
#         cycle_cmtes22 cmteid_cmtes22_noncands pacshort_cmtes22_noncands  \
# 14526          2022.0               C00236414              TransAmerica
# 14531          2022.0               C00236414              TransAmerica
# 182188         2022.0               C00034157                 AFLAC Inc
# 182214         2022.0               C00034157                 AFLAC Inc
# 223839         2022.0               C00109017                  AT&T Inc
#
#        affiliate_cmtes22_noncands ultorg_cmtes22_noncands recipid_cmtes22  \
# 14526                         NaN                AEGON NV       C00236414
# 14531                         NaN                AEGON NV       C00236414
# 182188                        NaN               AFLAC Inc       C00034157
# 182214                        NaN               AFLAC Inc       C00034157
# 223839                   AT&T Inc                AT&T Inc       C00109017
#
#        recipcode_cmtes22 party_cmtes22 primcode_cmtes22_noncands  \
# 14526                 PB           NaN                     F3100
# 14531                 PB           NaN                     F3100
# 182188                PB           NaN                     F3200
# 182214                PB           NaN                     F3200
# 223839                PB           NaN                     C4100
#
#        source_cmtes22_noncands sensitive_cmtes22_noncands  \
# 14526                    WAA21                          n
# 14531                    WAA21                          n
# 182188                   WAA21                          n
# 182214                   WAA21                          n
# 223839                   WAA21                          n
#
#         foreign_cmtes22_noncands  active_cmtes22_noncands client_lob_indus  \
# 14526                        1.0                      1.0         AEGON NV
# 14531                        1.0                      1.0         AEGON NV
# 182188                       0.0                      1.0        AFLAC Inc
# 182214                       0.0                      1.0        AFLAC Inc
# 223839                       0.0                      1.0         AT&T Inc
#
#        sub_lob_indus  total_lob_indus  year_lob_indus catcode_lob_indus  \
# 14526   Transamerica         510000.0          2022.0             F3100
# 14531   Transamerica         510000.0          2022.0             F3100
# 182188     AFLAC Inc        6110000.0          2022.0             F3200
# 182214     AFLAC Inc        6110000.0          2022.0             F3200
# 223839      AT&T Inc       11410000.0          2022.0             C4100
#
#        firstlast_cands22
# 14526    Jodey Arrington
# 14531    Jodey Arrington
# 182188   Jodey Arrington
# 182214   Jodey Arrington
# 223839   Jodey Arrington

# %%
df_member_by_name['amount_pacs22'].sum()
# Out:
# 1767918.0

# %%
# Most frequent donors.
df_member_by_name['client_lob_indus'].value_counts().head(50)
# Out:
# client_lob_indus
# American Hospital Assn                            140
# Blue Cross/Blue Shield                            110
# American Bankers Assn                              32
# Apollo Global Management                           15
# Credit Union National Assn                         13
# National Assn of Realtors                          12
# American Medical Assn                              12
# Lockheed Martin                                    12
# Illumina Inc                                       10
# Independent Community Bankers of America           10
# UnitedHealth Group                                 10
# General Motors                                      9
# Honeywell International                             8
# Abbott Laboratories                                 8
# National Federation of Independent Business         8
# Carlyle Group                                       7
# Wine & Spirits Wholesalers of America               7
# AstraZeneca PLC                                     6
# Pfizer Inc                                          6
# Chevron Corp                                        6
# National Assn of Home Builders                      6
# National Cotton Council                             6
# Merck KGaA                                          6
# McKesson Corp                                       6
# Marathon Petroleum                                  6
# H&R Block                                           6
# American Academy of Orthopaedic Surgeons            6
# National Beer Wholesalers Assn                      5
# National Assn of Real Estate Investment Trusts      5
# National Cattlemen's Beef Assn                      5
# Farm Credit Council                                 4
# Johnson & Johnson                                   4
# BAE Systems                                         4
# National Rifle Assn                                 4
# National Multifamily Housing Council                4
# Koch Industries                                     4
# MetLife Inc                                         4
# CH Boehringer Sohn                                  4
# National Stripper Well Assn                         4
# Exxon Mobil                                         4
# HCA Inc                                             4
# Loews Corp                                          4
# National Assn of Convenience Stores                 4
# Eli Lilly & Co                                      4
# National Apartment Assn                             4
# iHeartMedia Inc                                     4
# Occidental Petroleum                                4
# Sempra Energy                                       4
# Texas Farm Bureau                                   4
# American Israel Public Affairs Cmte                 4
# Name: count, dtype: int64

# %%
# Biggest donors.
df_donors = df_member_by_name.groupby('client_lob_indus')['amount_pacs22'].sum()
top_10_donors = df_donors.sort_values(ascending=False).head(50)
print(top_10_donors)
# Out:
# client_lob_indus
# American Hospital Assn                            280000.0
# Blue Cross/Blue Shield                            132000.0
# American Bankers Assn                              80000.0
# Credit Union National Assn                         45500.0
# Apollo Global Management                           37500.0
# UnitedHealth Group                                 37500.0
# Carlyle Group                                      35000.0
# National Assn of Realtors                          30000.0
# American Medical Assn                              30000.0
# AT&T Inc                                           20000.0
# Abbott Laboratories                                20000.0
# Valero Energy                                      20000.0
# Koch Industries                                    20000.0
# National Cotton Council                            17000.0
# Illumina Inc                                       15800.0
# Chevron Corp                                       15000.0
# General Motors                                     15000.0
# Fidelity Investments                               15000.0
# H&R Block                                          12000.0
# National Assn of Home Builders                     12000.0
# Lockheed Martin                                    12000.0
# AstraZeneca PLC                                    12000.0
# American Israel Public Affairs Cmte                10150.0
# National Assn of Real Estate Investment Trusts     10000.0
# American Institute of CPAs                         10000.0
# NextEra Energy                                     10000.0
# National Auto Dealers Assn                         10000.0
# National Multifamily Housing Council               10000.0
# National Beer Wholesalers Assn                     10000.0
# Occidental Petroleum                               10000.0
# Marathon Petroleum                                 10000.0
# LPL Financial Holdings                             10000.0
# American Crystal Sugar                             10000.0
# Select Medical Holdings                            10000.0
# Sempra Energy                                      10000.0
# Honeywell International                            10000.0
# Deere & Co                                         10000.0
# UBS AG                                             10000.0
# Exxon Mobil                                        10000.0
# Verizon Communications                             10000.0
# Farm Credit Council                                10000.0
# Xcel Energy                                        10000.0
# National Federation of Independent Business        10000.0
# Texas Farm Bureau                                   9600.0
# iHeartMedia Inc                                     9500.0
# Wine & Spirits Wholesalers of America               9000.0
# Pfizer Inc                                          9000.0
# CH Boehringer Sohn                                  8000.0
# Employee-Owned S Corporations of America            8000.0
# Independent Community Bankers of America            8000.0
# Name: amount_pacs22, dtype: float64

# %%
# Total donations by a particular donor.
donor_sum = df_member_by_name[df_member_by_name['client_lob_indus'] == 'American Hospital Assn']['amount_pacs22'].sum()
print(donor_sum)
# Out:
# 280000.0

# %%
df_member_by_cid = df_cands_or_indus[df_cands_or_indus['cid_cands22'] == member_cid]

# %%
df_member_by_cid['amount_pacs22'].sum()
# Out:
# 1767918.0

# %% [markdown]
# ---

# %% [markdown]
# #### Sanity checks ####

# %%
# Sanity check.
df_pacs22[df_pacs22['cid_pacs22'] == member_cid]['amount_pacs22'].sum()
# Out:
# 1020548

# %%
# Sanity check.
df_pac_other22[df_pac_other22['recipid_pac_other22'] == member_cid]['amount_pac_other22'].sum()
# Out:
# 1026562

# %%
# Sanity check.
df_indivs22[df_indivs22['recipid_indivs22'] == member_cid]['amount_indivs22'].sum()
# Out:
# 33559

# %%
# Final check.
df_pacs22[df_pacs22['cid_pacs22'] == member_cid]['amount_pacs22'].sum() \
    + df_pac_other22[df_pac_other22['recipid_pac_other22'] == member_cid]['amount_pac_other22'].sum() \
    + df_indivs22[df_indivs22['recipid_indivs22'] == member_cid]['amount_indivs22'].sum()
# Out:
# 2080669

# %%
# Save csv
df_pacs22[df_pacs22['cid_pacs22'] == member_cid].sort_values(by='amount_pacs22', ascending=False).to_csv('pacs22_' + member_cid + '.csv')
df_pac_other22[df_pac_other22['recipid_pac_other22'] == member_cid].sort_values(by='amount_pac_other22', ascending=False).to_csv('pac-other22_' + member_cid + '.csv')
df_indivs22[df_indivs22['recipid_indivs22'] == member_cid].sort_values(by='amount_indivs22', ascending=False).to_csv('indivs22_' + member_cid + '.csv')

# %%
# # Preview
# display(df_pacs22[df_pacs22['cid_pacs22'] == member_cid].head())
# display(df_pac_other22[df_pac_other22['recipid_pac_other22'] == member_cid].head())
# display(df_indivs22[df_indivs22['recipid_indivs22'] == member_cid].head())

# %% [markdown]
# ---

# %% [markdown]
# #### Group tests for the U.S. House Ways & Means committee members ####

# %%
# # SAVE THIS.
# ways_and_means_members22 = ['Jodey Arrington', 'Don Beyer', 'Earl Blumenauer', 'Vernon Buchanan', 'Mike Carey', 
#                             'Judy Chu', 'Danny K Davis', 'Suzan DelBene', 'Lloyd Doggett', 'Ron Estes', 
#                             'Dwight Evans', 'Randy Feenstra', 'Drew Ferguson', 'Michelle Fischbach', 'Brian Fitzpatrick', 
#                             'Kevin Hern', 'Brian Higgins', 'Mike Kelly', 'Dan Kildee', 'David Kustoff', 'Darin LaHood', 
#                             'John Larson', 'Nicole Malliotakis', 'Carol Miller', 'Blake Moore', 'Gwen Moore', 'Greg Murphy', 
#                             'Richard E Neal', 'Jimmy Panetta', 'Linda Sanchez', 'Brad Schneider', 'David Schweikert', 
#                             'Terri Sewell', 'Adrian Smith', 'Jason Smith', 'Lloyd Smucker', 'Michelle Steel', 
#                             'Greg Steube', 'Claudia Tenney', 'Mike Thompson', 'Beth Van Duyne']

# %% [markdown]
# ---

# %% [markdown]
# #### Misc experiments ####

# %%
# df_test_same_year = df_member[df_member['year_lob_indus'] == df_member['cycle_cands22']]

# %%
# df_test_same_year.head()

# %%
# df_test_same_year['amount_pacs22'].sum()

# %%
# df_lob_indus[df_lob_indus['client_lob_indus'] == 'AstraZeneca PLC']

# %%
# df_cands_or_indus[df_cands_or_indus['firstlast_cands22'] == 'Jodey Arrington'].to_csv('jodey_arrington.csv')

# %% [markdown]
# A few cells down I'm using catcodes to link industries, so double-check if that's the better way.

# %%
# df_exp1 = pd.merge(df_pacs22, df_cands22, left_on='cid_pacs22', right_on='cid_cands22', how='inner')
# df_exp1 = pd.merge(df_exp1, df_cmtes22, left_on='cid_pacs22', right_on='recipid_cmtes22', how='inner')

# %%
# df_exp2 = pd.merge(df_exp1, df_lob_indus[:len(df_exp1)], left_on='realcode_pacs22', right_on='catcode_lob_indus', how='inner')

# %%
# df_exp2.sample(3)

# %% [markdown]
# ---

# %% [markdown]
# ### Ways and Means ###

# %% [markdown]
# #### Member Details ####

# %%
wm_dems = ["Richard Neal",
"Brad Schneider",
"Jimmy Panetta",
"Bill Pascrell",
"Linda Sánchez",
"Terri Sewell",
"Gwen Moore",
"Tom Suozzi",
"Mike Thompson",
"John Larson",
"Stephanie Murphy",
"Donald Beyer",
"Earl Blumenauer",
"Brendan Boyle",
"Judy Chu",
"Danny Davis",
"Suzan DelBene",
"Lloyd Doggett",
"Dwight Evans",
"Jimmy Gomez",
"Brian Higgins",
"Steven Horsford",
"Dan Kildee",
"Ronald Kind"]

df_wm_dem_members = pd.DataFrame(wm_dems, columns=["firstlastp"])
df_wm_dem = pd.merge(df_cands22, df_wm_dem_members, left_on="firstlast_cands22", right_on="firstlastp", how="outer")

# %%
wm_rep = ["Jason Smith", 
"Vern Buchanan",
"Kevin Hern",
"Lloyd Smucker",
"Mike Kelly",
"Nicole Malliotakis",
"Randy Feenstra",
"Jodey Arrington",
"Greg Steube",
"Ron Estes",
"Adrian Smith",
"Beth Van Duyne",
"Carol Miller",
"Michelle Fischbach",
"Michelle Steel",
"Mike Carey",
"Blake Moore",
"Brad Wenstrup",
"Brian Fitzpatrick",
"Claudia Tenney",
"Darin LaHood",
"David Kustoff",
"David Schweikert",
"Drew Ferguson",
"Gregory Murphy"]

df_wm_rep_members = pd.DataFrame(wm_rep, columns=["firstlastp"])
df_wm_members = pd.merge(df_wm_dem, df_wm_rep_members, left_on="firstlast_cands22", right_on="firstlastp", how="inner")

# %%
df_wm_members.head()
# Out:
#    cycle_cands22 feccandid_cands22 cid_cands22     firstlastp_cands22  \
# 0         2022.0         H6NE03115   N00027623       Adrian Smith (R)
# 1         2022.0         H0TX24209   N00045167     Beth Van Duyne (R)
# 2         2022.0         H0UT01205   N00046598        Blake Moore (R)
# 3         2022.0         H2OH02085   N00033310      Brad Wenstrup (R)
# 4         2022.0         H6PA08277   N00038779  Brian Fitzpatrick (R)
#
#   party_cands22 distidrunfor_cands22 distidcurr_cands22 currcand_cands22  \
# 0             R                 NE03               NE03                Y
# 1             R                 TX24               TX24                Y
# 2             R                 UT01               UT01                Y
# 3             R                 OH02               OH02                Y
# 4             R                 PA01               PA01                Y
#
#   cyclecand_cands22 crpico_cands22 recipcode_cands22 nopacs_cands22  \
# 0                 Y              I                RW
# 1                 Y              I                RW
# 2                 Y              I                RW
# 3                 Y              I                RW
# 4                 Y              I                RW
#
#    firstlast_cands22 firstlastp_x       firstlastp_y
# 0       Adrian Smith          NaN       Adrian Smith
# 1     Beth Van Duyne          NaN     Beth Van Duyne
# 2        Blake Moore          NaN        Blake Moore
# 3      Brad Wenstrup          NaN      Brad Wenstrup
# 4  Brian Fitzpatrick          NaN  Brian Fitzpatrick

# %%
df_wm_members = df_wm_members.rename(columns={'feccandid_cands22': 'feccandid_member', 'cid_cands22': 'cid_member',
                              'firstlast_cands22': 'firstlast_member', 'party_cands22': 'party_member',
                              'currcand_cands22': 'currcand_member', 'cyclecand_cands22': 'cyclecand_member',
                              'crpico_cands22': 'crpico_member', 'recipcode_cands22': 'recipcode_member'})
df_wm_members = df_wm_members.drop(['cycle_cands22', 'firstlastp_cands22', 'distidrunfor_cands22', 'distidcurr_cands22', 'nopacs_cands22', 'firstlastp_x', 'firstlastp_y'], axis=1)

# %%
df_wm_members.head()
# Out:
#   feccandid_member cid_member party_member currcand_member cyclecand_member  \
# 0        H6NE03115  N00027623            R               Y                Y
# 1        H0TX24209  N00045167            R               Y                Y
# 2        H0UT01205  N00046598            R               Y                Y
# 3        H2OH02085  N00033310            R               Y                Y
# 4        H6PA08277  N00038779            R               Y                Y
#
#   crpico_member recipcode_member   firstlast_member
# 0             I               RW       Adrian Smith
# 1             I               RW     Beth Van Duyne
# 2             I               RW        Blake Moore
# 3             I               RW      Brad Wenstrup
# 4             I               RW  Brian Fitzpatrick

# %% [markdown]
# #### Members' Leadpac Details ####

# %%
# Note: a candidate may have multiple committees for continuity between
# cycles where accounts need to be reconciled over time.
df_wm_leadpacs = pd.merge(df_wm_members, df_cmtes22, left_on='cid_member', right_on='recipid_cmtes22', how='inner')
df_wm_leadpacs = df_wm_leadpacs.rename(columns={'cmteid_cmtes22': 'cmteid_leadpac', 'pacshort_cmtes22': 'pacshort_leadpac',
                                                'affiliate_cmtes22': 'affiliate_leadpac', 'ultorg_cmtes22': 'ultorg_leadpac',
                                                'recipid_cmtes22': 'recipid_leadpac', 'primcode_cmtes22': 'primcode_leadpac',
                                                'active_cmtes22': 'active_leadpac'})

df_wm_leadpacs = df_wm_leadpacs.drop(['cycle_cmtes22', 'recipcode_cmtes22', 'feccandid_cmtes22', 'party_cmtes22',
                                      'source_cmtes22', 'sensitive_cmtes22', 'foreign_cmtes22'], axis=1)

# %%
df_wm_leadpacs.head()
# Out:
#   feccandid_member cid_member party_member currcand_member cyclecand_member  \
# 0        H6NE03115  N00027623            R               Y                Y
# 1        H0TX24209  N00045167            R               Y                Y
# 2        H0TX24209  N00045167            R               Y                Y
# 3        H0UT01205  N00046598            R               Y                Y
# 4        H2OH02085  N00033310            R               Y                Y
#
#   crpico_member recipcode_member firstlast_member cmteid_leadpac  \
# 0             I               RW     Adrian Smith      C00412890
# 1             I               RW   Beth Van Duyne      C00714865
# 2             I               RW   Beth Van Duyne      C00718957
# 3             I               RW      Blake Moore      C00738872
# 4             I               RW    Brad Wenstrup      C00497818
#
#               pacshort_leadpac affiliate_leadpac               ultorg_leadpac  \
# 0    Adrian Smith for Congress               NaN    Adrian Smith for Congress
# 1  Beth Van Duyne for Congress               NaN  Beth Van Duyne for Congress
# 2          Van Duyne for TX-24               NaN          Van Duyne for TX-24
# 3     Blake Moore for Congress               NaN     Blake Moore for Congress
# 4        Wenstrup for Congress               NaN        Wenstrup for Congress
#
#   recipid_leadpac primcode_leadpac  active_leadpac
# 0       N00027623            Z1100               1
# 1       N00045167            Z1100               1
# 2       N00045167            Z1100               1
# 3       N00046598            Z1100               1
# 4       N00033310            Z1100               1

# %% [markdown]
# #### Members' leadpacs' revenues ####
# (Lacks identifying details)

# %%
# Link all transactions to candidate pacs.
# Get revenue only, filter out expenditures
# THIS MAY DISTORT THINGS! LOOK INTO THIS LATER.
df_pacs22_revenues = df_pacs22[df_pacs22['amount_pacs22'] > 0]

# %%
# Keep the "di" field, for now track both direct and indirect income:
# https://raw.githubusercontent.com/nketchum/si608exploration/refs/heads/main/docs/direct_vs_indirect_contrib.txt
df_wm_revenues = pd.merge(df_wm_leadpacs, df_pacs22_revenues, left_on='cid_member', right_on='cid_pacs22')
df_wm_revenues = df_wm_revenues.rename(columns={'fecrecno_pacs22': 'fecrecno_revenue', 'pacid_pacs22': 'pacid_revenue',
                                                'amount_pacs22': 'amount_revenue', 'date_pacs22': 'date_revenue',
                                                'realcode_pacs22': 'realcode_revenue', 'type_pacs22': 'type_revenue',
                                                'di_pacs22': 'di_revenue', 'feccandid_pacs22': 'feccandid_revenue'})
df_wm_revenues = df_wm_revenues.drop(['cycle_pacs22', 'cid_pacs22'], axis=1)

# %%
df_wm_revenues.sample(5)
# Out:
#       feccandid_member cid_member party_member currcand_member  \
# 12244        H8OK01157  N00040829            R               Y
# 4819         H4NY22051  N00036351            R               Y
# 9903         H6GA03113  N00039090            R               Y
# 11705        H6TX19099  N00038285            R               Y
# 3058         H6PA08277  N00038779            R               Y
#
#       cyclecand_member crpico_member recipcode_member   firstlast_member  \
# 12244                Y             I               RW         Kevin Hern
# 4819                 Y             I               RW     Claudia Tenney
# 9903                 Y             I               RW      Drew Ferguson
# 11705                Y             I               RW    Jodey Arrington
# 3058                 Y             I               RW  Brian Fitzpatrick
#
#       cmteid_leadpac                pacshort_leadpac affiliate_leadpac  \
# 12244      C00636092               Hern for Congress               NaN
# 4819       C00561183             Tenney for Congress               NaN
# 9903       C00607838      Drew Ferguson for Congress               NaN
# 11705      C00588657      Texans for Jodey Arrington               NaN
# 3058       C00607416  Brian Fitzpatrick for Congress               NaN
#
#                        ultorg_leadpac recipid_leadpac primcode_leadpac  \
# 12244               Hern for Congress       N00040829            Z1100
# 4819              Tenney for Congress       N00036351            Z1100
# 9903       Drew Ferguson for Congress       N00039090            Z1100
# 11705      Texans for Jodey Arrington       N00038285            Z1100
# 3058   Brian Fitzpatrick for Congress       N00038779            Z1100
#
#        active_leadpac     fecrecno_revenue pacid_revenue  amount_revenue  \
# 12244               1  4012620231720640011     C00586859            1000
# 4819                1  4012620221394370281     C00694323               5
# 9903                1  4020920221406086895     C00375360            1500
# 11705               1  4010420231665460606     C00211318            2500
# 3058                1  4012620221390079592     C00694323               1
#
#       date_revenue realcode_revenue type_revenue di_revenue feccandid_revenue
# 12244   2022-09-13            F4600          24K          D         H8OK01157
# 4819    2021-01-02            Z9600          24K          D         H4NY22051
# 9903    2021-12-14            H1130          24K          D         H6GA03113
# 11705   2022-11-04            F5100          24K          D         H6TX19099
# 3058    2021-01-07            Z9600          24K          D         H6PA08277

# %% [markdown]
# #### Members' leadpacs' transactions ####
#
# (Money flows + details of money flow)

# %%
df_wm_transactions = pd.merge(df_wm_revenues, df_cmtes22, left_on='pacid_revenue', right_on='cmteid_cmtes22', how='inner')
df_wm_transactions = df_wm_transactions.rename(columns={'cmteid_cmtes22': 'cmteid_transaction', 'pacshort_cmtes22': 'pacshort_transaction', 
                                                        'affiliate_cmtes22': 'affiliate_transaction', 'ultorg_cmtes22': 'ultorg_transaction', 
                                                        'recipid_cmtes22': 'recipid_transaction', 'recipcode_cmtes22': 'recipcode_transaction', 
                                                        'feccandid_cmtes22': 'feccandid_transaction', 'party_cmtes22': 'party_transaction', 
                                                        'source_cmtes22': 'source_transaction'})
df_wm_transactions = df_wm_transactions.drop(['cycle_cmtes22', 'primcode_cmtes22', 'sensitive_cmtes22', 'foreign_cmtes22', 'active_cmtes22'], axis=1)

# %%
df_wm_transactions
# Out:
#       feccandid_member cid_member party_member currcand_member  \
# 0            H6NE03115  N00027623            R               Y
# 1            H6NE03115  N00027623            R               Y
# 2            H6NE03115  N00027623            R               Y
# 3            H6NE03115  N00027623            R               Y
# 4            H6NE03115  N00027623            R               Y
# ...                ...        ...          ...             ...
# 19057        H8KS04112  N00040712            R               Y
# 19058        H8KS04112  N00040712            R               Y
# 19059        H8KS04112  N00040712            R               Y
# 19060        H8KS04112  N00040712            R               Y
# 19061        H8KS04112  N00040712            R               Y
#
#       cyclecand_member crpico_member recipcode_member firstlast_member  \
# 0                    Y             I               RW     Adrian Smith
# 1                    Y             I               RW     Adrian Smith
# 2                    Y             I               RW     Adrian Smith
# 3                    Y             I               RW     Adrian Smith
# 4                    Y             I               RW     Adrian Smith
# ...                ...           ...              ...              ...
# 19057                Y             I               RW        Ron Estes
# 19058                Y             I               RW        Ron Estes
# 19059                Y             I               RW        Ron Estes
# 19060                Y             I               RW        Ron Estes
# 19061                Y             I               RW        Ron Estes
#
#       cmteid_leadpac           pacshort_leadpac affiliate_leadpac  \
# 0          C00412890  Adrian Smith for Congress               NaN
# 1          C00412890  Adrian Smith for Congress               NaN
# 2          C00412890  Adrian Smith for Congress               NaN
# 3          C00412890  Adrian Smith for Congress               NaN
# 4          C00412890  Adrian Smith for Congress               NaN
# ...              ...                        ...               ...
# 19057      C00632067     Ron Estes for Congress               NaN
# 19058      C00632067     Ron Estes for Congress               NaN
# 19059      C00632067     Ron Estes for Congress               NaN
# 19060      C00632067     Ron Estes for Congress               NaN
# 19061      C00632067     Ron Estes for Congress               NaN
#
#                   ultorg_leadpac recipid_leadpac primcode_leadpac  \
# 0      Adrian Smith for Congress       N00027623            Z1100
# 1      Adrian Smith for Congress       N00027623            Z1100
# 2      Adrian Smith for Congress       N00027623            Z1100
# 3      Adrian Smith for Congress       N00027623            Z1100
# 4      Adrian Smith for Congress       N00027623            Z1100
# ...                          ...             ...              ...
# 19057     Ron Estes for Congress       N00040712            Z1100
# 19058     Ron Estes for Congress       N00040712            Z1100
# 19059     Ron Estes for Congress       N00040712            Z1100
# 19060     Ron Estes for Congress       N00040712            Z1100
# 19061     Ron Estes for Congress       N00040712            Z1100
#
#        active_leadpac     fecrecno_revenue pacid_revenue  amount_revenue  \
# 0                   1  2022720231732787170     C00456335            2500
# 1                   1  2031520231734695012     C00224725            2500
# 2                   1  4010420231665460439     C00000422            1500
# 3                   1  4010820221388306236     C00411900            2000
# 4                   1  4011120231682686527     C00118943            5000
# ...               ...                  ...           ...             ...
# 19057               1  4122820211386740562     C00107235            2000
# 19058               1  4122920221645454695     C00797670            2900
# 19059               1  4122920221645458512     C00797670            5000
# 19060               1  4122920221645458513     C00797670            2100
# 19061               1  4122920221645469757     C00039578            2500
#
#       date_revenue realcode_revenue type_revenue di_revenue feccandid_revenue  \
# 0       2022-10-06            F3100          24K          D         H6NE03115
# 1       2022-12-23            T8100          24K          D         H6NE03115
# 2       2022-10-31            H1100          24K          D         H6NE03115
# 3       2021-12-09            H4100          24K          D         H6NE03115
# 4       2022-10-31            F3300          24K          D         H6NE03115
# ...            ...              ...          ...        ...               ...
# 19057   2021-11-12            F5100          24K          D         H8KS04112
# 19058   2022-04-14            J5100          24K          D         H8KS04112
# 19059   2022-07-13            J5100          24K          D         H8KS04112
# 19060   2022-07-13            J5100          24K          D         H8KS04112
# 19061   2022-10-31            F3100          24K          D         H8KS04112
#
#       cmteid_transaction                   pacshort_transaction  \
# 0              C00456335            Physicians Mutual Insurance
# 1              C00224725                    Harley-Davidson Inc
# 2              C00000422                  American Medical Assn
# 3              C00411900                   Edwards Lifesciences
# 4              C00118943    Massachusetts Mutual Life Insurance
# ...                  ...                                    ...
# 19057          C00107235                 PricewaterhouseCoopers
# 19058          C00797670    American Israel Public Affairs Cmte
# 19059          C00797670    American Israel Public Affairs Cmte
# 19060          C00797670    American Israel Public Affairs Cmte
# 19061          C00039578  Council of Insurance Agents & Brokers
#
#                      affiliate_transaction  \
# 0                                      NaN
# 1                                      NaN
# 2                    American Medical Assn
# 3                                      NaN
# 4      Massachusetts Mutual Life Insurance
# ...                                    ...
# 19057                                  NaN
# 19058  American Israel Public Affairs Cmte
# 19059  American Israel Public Affairs Cmte
# 19060  American Israel Public Affairs Cmte
# 19061                                  NaN
#
#                           ultorg_transaction recipid_transaction  \
# 0                Physicians Mutual Insurance           C00456335
# 1                        Harley-Davidson Inc           C00224725
# 2                      American Medical Assn           C00000422
# 3                       Edwards Lifesciences           C00411900
# 4        Massachusetts Mutual Life Insurance           C00118943
# ...                                      ...                 ...
# 19057                 PricewaterhouseCoopers           C00107235
# 19058    American Israel Public Affairs Cmte           C00797670
# 19059    American Israel Public Affairs Cmte           C00797670
# 19060    American Israel Public Affairs Cmte           C00797670
# 19061  Council of Insurance Agents & Brokers           C00039578
#
#       recipcode_transaction feccandid_transaction party_transaction  \
# 0                        PB                   NaN               NaN
# 1                        PB                   NaN
# 2                        PB                   NaN               NaN
# 3                        PB                   NaN               NaN
# 4                        PB                   NaN               NaN
# ...                     ...                   ...               ...
# 19057                    PB                   NaN               NaN
# 19058                    PI                   NaN               NaN
# 19059                    PI                   NaN               NaN
# 19060                    PI                   NaN               NaN
# 19061                    PB                   NaN               NaN
#
#       primcode_transaction source_transaction
# 0                    F3100              WAA22
# 1                    T8100              WAA19
# 2                    H1100              WAA21
# 3                    H4100              WAA21
# 4                    F3300              WAA21
# ...                    ...                ...
# 19057                F5100              WAA21
# 19058                J5100              WAA22
# 19059                J5100              WAA22
# 19060                J5100              WAA22
# 19061                F3100              WAA21
#
# [19062 rows x 33 columns]

# %%
# Donations by United Postmasters & Managers of America, who gave to Claudia Tenney, N00036351, linked from "pacid_pacs22" in df_wm_transactions
df_pacs22[df_pacs22['pacid_pacs22'] == 'C00100404']
# Out:
#         cycle_pacs22      fecrecno_pacs22 pacid_pacs22 cid_pacs22  \
# 1469            2022  4010320231645675381    C00100404  N00035215
# 1470            2022  4010320231645675382    C00100404  N00029891
# 1471            2022  4010320231645675383    C00100404  N00025766
# 1472            2022  4010320231645675384    C00100404  N00036351
# 1473            2022  4010320231645675385    C00100404  N00030670
# ...              ...                  ...          ...        ...
# 747943          2022  4121720221637693851    C00100404  N00044223
# 747944          2022  4121720221637693852    C00100404  N00046030
# 747945          2022  4121720221637693853    C00100404  N00029139
# 747946          2022  4121720221637693854    C00100404  N00045905
# 747947          2022  4121720221637693858    C00100404  N00038397
#
#         amount_pacs22 date_pacs22 realcode_pacs22 type_pacs22 di_pacs22  \
# 1469              100  2022-06-07           L1500         24K         D
# 1470              500  2022-06-13           L1500         24K         D
# 1471             2000  2022-06-14           L1500         24K         D
# 1472             2000  2022-06-21           L1500         24K         D
# 1473             2000  2022-06-21           L1500         24K         D
# ...               ...         ...             ...         ...       ...
# 747943           1000  2022-09-27           L1500         24K         D
# 747944           5000  2022-09-28           L1500         24K         D
# 747945           1000  2022-09-28           L1500         24K         D
# 747946           1000  2022-09-29           L1500         24K         D
# 747947           2500  2022-10-13           L1500         24K         D
#
#        feccandid_pacs22
# 1469          H2IL02172
# 1470          H8VA11062
# 1471          H2LA02149
# 1472          H4NY22051
# 1473          S6IN00191
# ...                 ...
# 747943        S0AZ00350
# 747944        H0NY02234
# 747945        H8IL14067
# 747946        H0IN01150
# 747947        S6NH00091
#
# [95 rows x 10 columns]

# %%
# Using the committee in 
df_cmtes22[df_cmtes22['cmteid_cmtes22'] == 'C00100404']
# Out:
#      cycle_cmtes22 cmteid_cmtes22                          pacshort_cmtes22  \
# 485           2022      C00100404  United Postmasters & Managers of America
#
#                             affiliate_cmtes22  \
# 485  United Postmasters & Managers of America
#
#                                ultorg_cmtes22 recipid_cmtes22  \
# 485  United Postmasters & Managers of America       C00100404
#
#     recipcode_cmtes22 feccandid_cmtes22 party_cmtes22 primcode_cmtes22  \
# 485                PL               NaN           NaN            L1500
#
#     source_cmtes22 sensitive_cmtes22  foreign_cmtes22  active_cmtes22
# 485          WAA21                 n                0               1

# %%
df_cmtes22[df_cmtes22['cmteid_cmtes22'] == 'C00456335']
# Out:
#       cycle_cmtes22 cmteid_cmtes22             pacshort_cmtes22  \
# 3184           2022      C00456335  Physicians Mutual Insurance
#
#      affiliate_cmtes22               ultorg_cmtes22 recipid_cmtes22  \
# 3184               NaN  Physicians Mutual Insurance       C00456335
#
#      recipcode_cmtes22 feccandid_cmtes22 party_cmtes22 primcode_cmtes22  \
# 3184                PB               NaN           NaN            F3100
#
#      source_cmtes22 sensitive_cmtes22  foreign_cmtes22  active_cmtes22
# 3184          WAA22                 N                0               1
