# %%
import pandas as pd
import numpy as np

# %%
# Dataset description:
# https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20lob_lobbyists.htm
columns_lob_lobbyist = ['uniqid', 'lobbyist_lastname_std', 'lobbyist_firstname_std', 'lobbyist_lastname_raw', 
                     'lobbyist_firstname_raw', 'lobbyist_id', 'year', 'officialposition', 'cid', 'formercongmem']

columns_lob_lobbyist = dict(enumerate(columns_lob_lobbyist))

# %%
df = pd.read_csv('../../data/open_secrets/Lobby/lob_lobbyist.csv', on_bad_lines='skip', sep=',', header=None, na_values=['N/A', 'NA'], encoding='ISO-8859-1')
df = df.rename(columns=columns_lob_lobbyist)

# %%
# Get rid of the pipes on both sides of the data.

df = df.map(lambda x: x.replace('|', '') if type(x) == str else x)

df['year'] = pd.to_numeric(df['year'], errors='coerce')
df = df.dropna(subset=['year'])
df['year'] = df['year'].astype(int)

# %%
# Look at most recent data.
df_recent = df[df['year'] >= 2014]

# %%
pd.options.display.max_columns = None
df_recent
# Out:
#                                        uniqid lobbyist_lastname_std  \
# 2152     7EAB24E9-C597-4E1D-A04D-F32C8A898D44             MACKINNON
# 2153     7EAB24E9-C597-4E1D-A04D-F32C8A898D44               MORTIER
# 2154     7EAB24E9-C597-4E1D-A04D-F32C8A898D44                  RYAN
# 2155     7EADE25B-D4EF-4965-A17C-108BB6D89BA0                 KELLY
# 2156     7EADE25B-D4EF-4965-A17C-108BB6D89BA0               THOMSON
# ...                                       ...                   ...
# 3148495  fa2e5ac1-1463-40b7-8f2b-7769134fc4b6                 ADAIR
# 3148496  fa2e5ac1-1463-40b7-8f2b-7769134fc4b6             GARFINKEL
# 3148497  fa2e5ac1-1463-40b7-8f2b-7769134fc4b6                  KATZ
# 3148498  fa2e5ac1-1463-40b7-8f2b-7769134fc4b6                KELLER
# 3148499  fd8cfc5a-d0cd-4310-ad19-4e48e0ccb66e             HITCHCOCK
#
#         lobbyist_firstname_std lobbyist_lastname_raw lobbyist_firstname_raw  \
# 2152                      JEFF             MacKinnon              Jeffrey M
# 2153                      JEFF               Mortier                   Jeff
# 2154                    THOMAS                  Ryan               Thomas M
# 2155                   KEVIN F                 Kelly                Kevin F
# 2156                    JASPER               Thomson                 Jasper
# ...                        ...                   ...                    ...
# 3148495             JOHN LUCAS                 Adair                  Lucas
# 3148496                 ANDREW             Garfinkel                 Andrew
# 3148497                 ALAN M                  Katz                   Alan
# 3148498                 THOMAS                Keller               Thomas C
# 3148499              ELIZABETH             Hitchcock              Elizabeth
#
#           lobbyist_id  year  \
# 2152     Y0000040530L  2014
# 2153     Y0000047083L  2014
# 2154     Y0000025838L  2014
# 2155     Y0000041925L  2014
# 2156     Y0000006654L  2014
# ...               ...   ...
# 3148495  YX000058147L  2023
# 3148496  Y0000008935L  2023
# 3148497  Y0000052389L  2023
# 3148498  Y0000017161L  2023
# 3148499  Y0000012367L  2023
#
#                                           officialposition cid formercongmem
# 2152     LD & LA Rep. Joe Barton (R-Texas) LD & LA Rep....                 n
# 2153     Prof Staff on E&C Cmte and LA Rep Whitfield Pr...                 n
# 2154                                                                       n
# 2155                                                                       n
# 2156                                                                       n
# ...                                                    ...  ..           ...
# 3148495                                                                    n
# 3148496                                                                    n
# 3148497                                                                    n
# 3148498                                                                    n
# 3148499                                                                    n
#
# [1325293 rows x 10 columns]

# %%
# Lobbyists who have cid's (were in government at one time)
df[df['cid'] != '']
# Out:
#                                        uniqid lobbyist_lastname_std  \
# 2        5CBE61EC-87F1-401E-9D57-620975C9A1F8              COSTELLO
# 14       287F0E68-3350-4D72-89BD-63A9D0B40F80               BENTSEN
# 42       6979F7B5-FCB2-447C-95A0-7C6EE7EA9350                MICHEL
# 85       A5D185B7-3D2B-4C6B-B881-6385E3918B89               ENGLISH
# 100      8847A337-FE5C-41F1-96FF-B268BC59F655                BREAUX
# ...                                       ...                   ...
# 3148194  ff38946f-5c59-4bc2-b36b-af24cb95ff14                 ROYCE
# 3148219  07853b06-7ff2-4c3a-896f-27d5b1746c7b                 POMBO
# 3148273  3c56191e-4b7c-436a-a79a-b5faee31d70d                 POMBO
# 3148436  c69d22ef-35a9-4e78-958b-2a246ef8c93b                 POMBO
# 3148488  f2777a95-e1e3-4dfe-b85f-256ffc89faf0                 POMBO
#
#         lobbyist_firstname_std lobbyist_lastname_raw lobbyist_firstname_raw  \
# 2                         RYAN              Costello                   Ryan
# 14                    LLOYD M.               Bentsen                  Lloyd
# 42                   ROBERT H.                Michel               Robert H
# 85                       GLENN               English           Glenn Lee Jr
# 100                       JOHN                Breaux                   John
# ...                        ...                   ...                    ...
# 3148194         EDWARD RANDALL                 Royce                 Edward
# 3148219                RICHARD                 Pombo                Richard
# 3148273                RICHARD                 Pombo                Richard
# 3148436                RICHARD                 Pombo                Richard
# 3148488                RICHARD                 Pombo                Richard
#
#           lobbyist_id  year                               officialposition  \
# 2        Y0000027292L  2002                                            N/A
# 14       Y0000005721L  2000                                            N/A
# 42       Y0000019350L  2002                                            N/A
# 85       Y0000014080L  1999                                            N/A
# 100      Y0000041198L  2006                          UNITED STATES SENATOR
# ...               ...   ...                                            ...
# 3148194  Y0000056481L  2023
# 3148219  Y0000048209L  2023                      Former Member of Congress
# 3148273  Y0000048209L  2023                      Former Member of Congress
# 3148436  Y0000048209L  2023                      Former Member of Congress
# 3148488  Y0000048209L  2023  Former Member of the House of Representatives
#
#                cid formercongmem
# 2        N00031064             y
# 14       N00006003             y
# 42       N00004929             y
# 85       N00005560             y
# 100      N00005385             y
# ...            ...           ...
# 3148194  N00008264             y
# 3148219  N00007516             y
# 3148273  N00007516             y
# 3148436  N00007516             y
# 3148488  N00007516             y
#
# [127442 rows x 10 columns]
