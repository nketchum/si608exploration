# %%
import pandas as pd
import numpy as np

# %%
# Dataset description:
# https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20527%20Expenditures.htm
columns_expends527 = ['rpt', 'formid', 'schbid', 'orgname', 'ein', 'recipient', 
                    'recipientcrp', 'amount', 'date', 'expcode', 'source', 
                    'purpose', 'addr1', 'addr2', 'city', 'state', 'zip',
                    'employer', 'occupation']
columns_expends527 = dict(enumerate(columns_expends527))

# %%
df = pd.read_csv('../../data/open_secrets/527/expends527.csv', on_bad_lines='skip', sep=',', header=None, na_values=['N/A', 'NA'], encoding='ISO-8859-1')
df = df.rename(columns=columns_expends527)
# Out:
# /var/folders/rm/kxyn59hn41j35zkp54p83xp40000gn/T/ipykernel_87031/225026706.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../data/open_secrets/527/expends527.csv', on_bad_lines='skip', sep=',', header=None, na_values=['N/A', 'NA'], encoding='ISO-8859-1')

# %%
# Get rid of the pipes on both sides of the data.
df = df.map(lambda x: x.replace('|', '') if type(x) == str else x)

# Other cleanup.
df['formid'] = df['formid'].apply(lambda x: int(x))
df['schbid'] = df['schbid'].apply(lambda x: int(x))

df['date'] = pd.to_datetime(df['date'], format='%m/%d/%Y', errors='coerce')
df = df.dropna(subset=['date'])

df['amount'] = pd.to_numeric(df['amount'], errors='coerce')
df = df.dropna(subset=['amount'])
df['amount'] = df['amount'].astype(int)

df['ein'] = pd.to_numeric(df['ein'], errors='coerce')
df = df.dropna(subset=['ein'])
df['ein'] = df['ein'].astype(int)

df['zip'] = pd.to_numeric(df['zip'], errors='coerce')
df = df.dropna(subset=['zip'])
df['zip'] = df['zip'].astype(int)

# %%
pd.options.display.max_columns = None
df
# Out:
#           rpt   formid    schbid                           orgname        ein  \
# 0        Q210  9595787   2016057  Republican State Leadership Cmte   50532524
# 1        Q210  9595787   2016059  Republican State Leadership Cmte   50532524
# 2        Q210  9595791   2016223                             GOPAC  521237780
# 3        Q210  9595791   2016225                             GOPAC  521237780
# 4        Q210  9595791   2016228                             GOPAC  521237780
# ...       ...      ...       ...                               ...        ...
# 3629596  Q222  9714685  40531124               ActBlue Non-Federal  202517748
# 3629597  Q222  9714685  40531135               ActBlue Non-Federal  202517748
# 3629598  Q222  9714685  40531136               ActBlue Non-Federal  202517748
# 3629599  Q222  9714685  40531144               ActBlue Non-Federal  202517748
# 3629600  Q222  9714685  40531151               ActBlue Non-Federal  202517748
#
#                   recipient                   recipientcrp  amount       date  \
# 0                   VERIZON         Verizon Communications     125 2010-04-16
# 1          VERIZON WIRELESS               Verizon Wireless     141 2010-04-09
# 2                       ADP  Automatic Data Processing Inc     414 2010-04-09
# 3                       ADP  Automatic Data Processing Inc      78 2010-04-23
# 4          AMERICAN EXPRESS               American Express       1 2010-04-26
# ...                     ...                            ...     ...        ...
# 3629596  SMITH FOR GOVERNOR             Smith for Governor      25 2022-04-10
# 3629597  SMITH FOR GOVERNOR             Smith for Governor     100 2022-04-24
# 3629598  SMITH FOR GOVERNOR             Smith for Governor      10 2022-04-03
# 3629599  SMITH FOR GOVERNOR             Smith for Governor     100 2022-04-24
# 3629600  SMITH FOR GOVERNOR             Smith for Governor      10 2022-04-10
#
#         expcode source                            purpose  \
# 0           A70   @new                          TELEPHONE
# 1           A70   @new                         CELL PHONE
# 2           W10   @new                      PAYROLL TAXES
# 3           W10   @new                   PAYROLL SERVICES
# 4           U00  tempU  AMEX PYMT $6634.00 DETAIL FOLLOWS
# ...         ...    ...                                ...
# 3629596     R40   @new             Political contribution
# 3629597     R40   @new             Political contribution
# 3629598     R40   @new             Political contribution
# 3629599     R40   @new             Political contribution
# 3629600     R40   @new             Political contribution
#
#                           addr1 addr2           city state    zip employer  \
# 0                 PO BOX 660720               DALLAS    TX  75266       NA
# 1                  PO BOX 25505        LEHIGH VALLEY    PA  18002       NA
# 2        8094 SAND PIPER CIRCLE          WHITE MARSH    MD  21236       NA
# 3        8094 SAND PIPER CIRCLE          WHITE MARSH    MD  21236       NA
# 4                 P.O. BOX 1270               NEWARK    NJ   7101       NA
# ...                         ...   ...            ...   ...    ...      ...
# 3629596    2601 S MINNESOTA AVE          SIOUX FALLS    SD  57105       NA
# 3629597    2601 S MINNESOTA AVE          SIOUX FALLS    SD  57105       NA
# 3629598    2601 S MINNESOTA AVE          SIOUX FALLS    SD  57105       NA
# 3629599    2601 S MINNESOTA AVE          SIOUX FALLS    SD  57105       NA
# 3629600    2601 S MINNESOTA AVE          SIOUX FALLS    SD  57105       NA
#
#         occupation
# 0               NA
# 1               NA
# 2               NA
# 3               NA
# 4               NA
# ...            ...
# 3629596         NA
# 3629597         NA
# 3629598         NA
# 3629599         NA
# 3629600         NA
#
# [3623738 rows x 19 columns]

# %%
# We can look up committees using
# ein.
df[df['ein'] == 464747846]
# Out:
#          rpt   formid   schbid                         orgname        ein  \
# 396732  Q114  9625127  3282243  Brian D Goldberg for US Senate  464747846
# 398126  Q214  9627879  3426204  Brian D Goldberg for US Senate  464747846
# 399177  Q114  9625127  3282242  Brian D Goldberg for US Senate  464747846
# 401208  Q214  9627874  3426112  Brian D Goldberg for US Senate  464747846
# 401310  Q114  9625127  3282244  Brian D Goldberg for US Senate  464747846
# 401724  Q214  9627879  3426206  Brian D Goldberg for US Senate  464747846
# 402170  Q214  9627879  3426208  Brian D Goldberg for US Senate  464747846
# 403111  Q214  9627874  3426113  Brian D Goldberg for US Senate  464747846
# 403113  Q214  9627879  3426203  Brian D Goldberg for US Senate  464747846
# 403114  Q214  9627879  3426205  Brian D Goldberg for US Senate  464747846
# 403487  Q214  9627879  3426207  Brian D Goldberg for US Senate  464747846
# 411574  Q314  9630463  3813195  Brian D Goldberg for US Senate  464747846
# 420493  Q414  9631968  4051134  Brian D Goldberg for US Senate  464747846
# 427402  Q414  9633702  4177551  Brian D Goldberg for US Senate  464747846
#
#                     recipient           recipientcrp  amount       date  \
# 396732                Staples            Staples Inc    1146 2014-03-31
# 398126              Imprinsic              Imprinsic    2000 2014-05-30
# 399177              Imprinsic              Imprinsic    2000 2014-03-18
# 401208       CWP & Associates            Cwp & Assoc    1000 2014-04-11
# 401310  New Jersey Reagan Day  New Jersey Reagan Day     500 2014-02-28
# 401724       Overnight Prints       Overnight Prints     760 2014-05-23
# 402170               Withheld               Withheld     536 2014-06-30
# 403111               Withheld               Withheld     245 2014-05-14
# 403113              Imprinsic              Imprinsic    1999 2014-05-17
# 403114       Overnight Prints       Overnight Prints     131 2014-05-19
# 403487                Staples            Staples Inc      48 2014-05-22
# 411574               Withheld               Withheld     349 2014-09-30
# 420493               Withheld               Withheld     148 2014-11-24
# 427402               Withheld               Withheld     133 2014-12-31
#
#        expcode source                          purpose  \
# 396732     U10   @new  Photocopies and office supplies
# 398126     U00  tempU               Marketing Services
# 399177     U00  tempU               Marketing Services
# 401208     F50   @new           Fundraising Consulting
# 401310     U30  tempE           Table sponsor at event
# 401724     U00  tempU                       Palm cards
# 402170     U00  ManAM                         Withheld
# 403111     U00  ManAM                         Withheld
# 403113     U00  tempU               Marketing Services
# 403114     U00  tempU                   Business Cards
# 403487     U10   @new       Copies and office supplies
# 411574     U00   same                         Withheld
# 420493     U00   same                         Withheld
# 427402     U00  tempU            Website and marketing
#
#                          addr1    addr2           city state    zip employer  \
# 396732           3140 Route 35                  Hazlet    NJ   7730      N/A
# 398126  228 Kings Highway East             Haddonfield    NJ   8033      N/A
# 399177  228 Kings Highway East             Haddonfield    NJ   8033      N/A
# 401208    4979 Land Bridge Ave  Apt 104   Palm Harbour    FL  34683      N/A
# 401310        42 Carlson Place           Lake Hiawatha    NJ   7034      N/A
# 401724  7582 Las Vegas Blvd. S               Las Vegas    NV  89123      N/A
# 402170              PO Box 356              Livingston    NJ   7039      N/A
# 403111              PO Box 356              Livingston    NJ   7039      N/A
# 403113  228 Kings Highway East             Haddonfield    NJ   8033      N/A
# 403114  7582 Las Vegas Blvd. S               Las Vegas    NV  89123      N/A
# 403487           3140 Route 35                  Hazlet    NJ   7730      N/A
# 411574              PO Box 356              Livingston    NJ   7039      N/A
# 420493              PO Box 356              Livingston    NJ   7039      N/A
# 427402              PO Box 356              Livingston    NJ   7039      N/A
#
#        occupation
# 396732        N/A
# 398126        N/A
# 399177        N/A
# 401208        N/A
# 401310        N/A
# 401724        N/A
# 402170        N/A
# 403111        N/A
# 403113        N/A
# 403114        N/A
# 403487        N/A
# 411574        N/A
# 420493        N/A
# 427402        N/A
