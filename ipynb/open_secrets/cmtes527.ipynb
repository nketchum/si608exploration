# %%
import pandas as pd
import numpy as np

# %%
# Dataset description:
# https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20527%20Cmtes.htm
columns_cmtes527 = ['cycle', 'rpt', 'ein', 'crp527name', 'affiliate', 'ultorg', 
                    'recipcode', 'cmteid', 'cid', 'eccmteid', 'party', 
                    'primcode', 'source', 'ffreq', 'ctype', 'csource', 'viewpt',
                    'comments', 'state']
columns_cmtes527 = dict(enumerate(columns_cmtes527))

# %%
df = pd.read_csv('../../data/open_secrets/527/cmtes527.csv', on_bad_lines='skip', sep=',', header=None, na_values=['N/A', 'NA'])
df = df.rename(columns=columns_cmtes527)

# %%
# Get rid of the pipes on both sides of the data.
df = df.applymap(lambda x: x.replace('|', '') if type(x) == str else x)

# Other cleanup.
df['cycle'] = df['cycle'].apply(lambda x: int(x))
df['ein'] = df['ein'].apply(lambda x: int(x))

# %%
df_recent = df[df['cycle'] >= 2014]
df_recent = df_recent.reset_index(drop=True)

# %%
pd.options.display.max_columns = None
df_recent
# Out:
#       cycle   rpt        ein                                       crp527name  \
# 0      2014  Q114  464747846                   Brian D Goldberg for US Senate
# 1      2014  Q213  462000473                         Advocacy for Action Fund
# 2      2014  Q214  463575406               Seeking Transparency in Government
# 3      2014  Q414  522257109  International Brotherhood of Electrical Workers
# 4      2014  Q413  273202261                                   AFT Solidarity
# ...     ...   ...        ...                                              ...
# 2295   2014  Q213  453599950                       Wright McLeod for Congress
# 2296   2014  Q414  464747846                   Brian D Goldberg for US Senate
# 2297   2014  Q214  274900573               Americans for Liberty & Prosperity
# 2298   2014  Q314  454308347                        Shuttleworth for Congress
# 2299   2014  Q213  205302111                            Economic Freedom Fund
#
#                       affiliate  \
# 0
# 1
# 2
# 3
# 4
# ...                         ...
# 2295
# 2296
# 2297
# 2298  Bruce Shuttleworth (D-VA)
# 2299
#
#                                                ultorg recipcode     cmteid  \
# 0                      Brian D Goldberg for US Senate        RL  C00558874
# 1                            Advocacy for Action Fund        PI
# 2                  Seeking Transparency in Government        PI
# 3     International Brotherhood of Electrical Workers        PL  C00027342
# 4                     American Federation of Teachers        PL
# ...                                               ...       ...        ...
# 2295                       Wright McLeod for Congress        RC
# 2296                   Brian D Goldberg for US Senate        RL  C00558874
# 2297               Americans for Liberty & Prosperity        PI
# 2298                        Shuttleworth for Congress        DL
# 2299                            Economic Freedom Fund        PI
#
#             cid   eccmteid party primcode source ffreq ctype csource viewpt  \
# 0     N00036203                R    Z1100   Rept     Q     F    Rept      C
# 1                            NaN    J7500  webMS     Q     S   webMS      L
# 2                                   Y0000            Q     S    Rept      X
# 3                                   LC150    PAC     Q     F    Name      L
# 4                                   L1300   Name     Q     F    Name      L
# ...         ...        ...   ...      ...    ...   ...   ...     ...    ...
# 2295  N00033605                R    Z1100   Rept     Q     F    Rept      C
# 2296  N00036203                R    Z1100   Rept     Q     F    Rept      C
# 2297                                J1100   Rept     Q     F    Rept      C
# 2298  N00034161                D    Z1200   Rept     Q     F    Rept      L
# 2299             C30000541   NaN    J1100  webMS     Q     F   webMS      C
#
#      comments state
# 0                NJ
# 1                GA
# 2                FL
# 3                DC
# 4                DC
# ...       ...   ...
# 2295             GA
# 2296             NJ
# 2297             FL
# 2298             VA
# 2299             CA
#
# [2300 rows x 19 columns]

# %%
# Brian D Goldberg's non-mutable candidate id.
# These are his quarterly reports.
df_cand = df[df['cid'] == 'N00036203']
df_cand
# Out:
#        cycle   rpt        ein                      crp527name affiliate  \
# 13      2014  Q114  464747846  Brian D Goldberg for US Senate
# 3465    2014  Q214  464747846  Brian D Goldberg for US Senate
# 14609   2014  Q314  464747846  Brian D Goldberg for US Senate
# 15068   2014  Q414  464747846  Brian D Goldberg for US Senate
#
#                                ultorg recipcode     cmteid        cid  \
# 13     Brian D Goldberg for US Senate        RL  C00558874  N00036203
# 3465   Brian D Goldberg for US Senate        RL  C00558874  N00036203
# 14609  Brian D Goldberg for US Senate        RL  C00558874  N00036203
# 15068  Brian D Goldberg for US Senate        RL  C00558874  N00036203
#
#       eccmteid party primcode source ffreq ctype csource viewpt comments state
# 13                 R    Z1100   Rept     Q     F    Rept      C             NJ
# 3465               R    Z1100   Rept     Q     F    Rept      C             NJ
# 14609              R    Z1100   Rept     Q     F    Rept      C             NJ
# 15068              R    Z1100   Rept     Q     F    Rept      C             NJ

# %%
# Brian D Goldberg's election committee id.
# Same results as above.
df[df['cmteid'] == 'C00558874']
# Out:
#        cycle   rpt        ein                      crp527name affiliate  \
# 13      2014  Q114  464747846  Brian D Goldberg for US Senate
# 3465    2014  Q214  464747846  Brian D Goldberg for US Senate
# 14609   2014  Q314  464747846  Brian D Goldberg for US Senate
# 15068   2014  Q414  464747846  Brian D Goldberg for US Senate
#
#                                ultorg recipcode     cmteid        cid  \
# 13     Brian D Goldberg for US Senate        RL  C00558874  N00036203
# 3465   Brian D Goldberg for US Senate        RL  C00558874  N00036203
# 14609  Brian D Goldberg for US Senate        RL  C00558874  N00036203
# 15068  Brian D Goldberg for US Senate        RL  C00558874  N00036203
#
#       eccmteid party primcode source ffreq ctype csource viewpt comments state
# 13                 R    Z1100   Rept     Q     F    Rept      C             NJ
# 3465               R    Z1100   Rept     Q     F    Rept      C             NJ
# 14609              R    Z1100   Rept     Q     F    Rept      C             NJ
# 15068              R    Z1100   Rept     Q     F    Rept      C             NJ

# %%
# Andre Carson's election committee id.
# No results
df[df['cmteid'] == 'C00442921']
# Out:
# Empty DataFrame
# Columns: [cycle, rpt, ein, crp527name, affiliate, ultorg, recipcode, cmteid, cid, eccmteid, party, primcode, source, ffreq, ctype, csource, viewpt, comments, state]
# Index: []

# %%
df[df['cmteid'] == 'C00401224'] # Act Blue PAC
# Out:
#        cycle   rpt        ein           crp527name affiliate   ultorg  \
# 31      2010  Q210  202517748  ActBlue Non-Federal            ActBlue
# 646     2012  Q212  202517748  ActBlue Non-Federal            ActBlue
# 1310    2010  Q410  202517748  ActBlue Non-Federal            ActBlue
# 2779    2006  Q406  202517748              ActBlue            ActBlue
# 2781    2012  Q112  202517748  ActBlue Non-Federal            ActBlue
# 2840    2008  Q208  202517748              ActBlue            ActBlue
# 2879    2014  Q413  202517748  ActBlue Non-Federal            ActBlue
# 3349    2012  Q412  202517748  ActBlue Non-Federal            ActBlue
# 4012    2014  Q213  202517748  ActBlue Non-Federal            ActBlue
# 4522    2010  Q409  202517748  ActBlue Non-Federal            ActBlue
# 4781    2012  Q411  202517748  ActBlue Non-Federal            ActBlue
# 5291    2008  Q308  202517748              ActBlue            ActBlue
# 5514    2010  Q209  202517748  ActBlue Non-Federal            ActBlue
# 5789    2006  Q205  202517748              ActBlue            ActBlue
# 6064    2008  Q408  202517748              ActBlue            ActBlue
# 6728    2008  Q207  202517748              ActBlue            ActBlue
# 7810    2006  Q306  202517748              ActBlue            ActBlue
# 7901    2014  Q114  202517748  ActBlue Non-Federal            ActBlue
# 8151    2012  Q211  202517748  ActBlue Non-Federal            ActBlue
# 8386    2006  Q405  202517748              ActBlue            ActBlue
# 8812    2014  Q414  202517748  ActBlue Non-Federal            ActBlue
# 8922    2012  Q311  202517748  ActBlue Non-Federal            ActBlue
# 9147    2014  Q113  202517748  ActBlue Non-Federal            ActBlue
# 9964    2006  Q106  202517748              ActBlue            ActBlue
# 10378   2008  Q108  202517748              ActBlue            ActBlue
# 10447   2010  Q310  202517748  ActBlue Non-Federal            ActBlue
# 10637   2010  Q110  202517748  ActBlue Non-Federal            ActBlue
# 10743   2006  Q206  202517748              ActBlue            ActBlue
# 10914   2012  Q111  202517748  ActBlue Non-Federal            ActBlue
# 10921   2008  Q407  202517748              ActBlue            ActBlue
#
#       recipcode     cmteid cid eccmteid party primcode source ffreq ctype  \
# 31           PI  C00401224                       J1200  WebDA     Q     F
# 646          PI  C00401224                NaN    J1200  WebDA     M     F
# 1310         PI  C00401224                NaN    J1200  WebDA     M     F
# 2779         PI  C00401224                       J1200  WebDA     Q     F
# 2781         PI  C00401224                NaN    J1200  WebDA     M     F
# 2840         PI  C00401224                       J1200  WebDA     Q     F
# 2879         PI  C00401224                NaN    J1200  WebDA     M     F
# 3349         PI  C00401224                NaN    J1200  WebDA     M     F
# 4012         PI  C00401224                NaN    J1200  WebDA     M     F
# 4522         PI  C00401224                       J1200  WebDA     Q     F
# 4781         PI  C00401224                NaN    J1200  WebDA     M     F
# 5291         PI  C00401224                       J1200  WebDA     Q     F
# 5514         PI  C00401224                       J1200  WebDA     Q     F
# 5789         PI  C00401224                NaN    J1200  WebDA     Q     F
# 6064         PI  C00401224                       J1200  WebDA     Q     F
# 6728         PI  C00401224                       J1200  WebDA     Q     F
# 7810         PI  C00401224                       J1200  WebDA     Q     F
# 7901         PI  C00401224                NaN    J1200  WebDA     M     F
# 8151         PI  C00401224                NaN    J1200  WebDA     M     F
# 8386         PI  C00401224                       J1200  WebDA     Q     F
# 8812         PI  C00401224                NaN    J1200  WebDA     M     F
# 8922         PI  C00401224                NaN    J1200  WebDA     M     F
# 9147         PI  C00401224                NaN    J1200  WebDA     M     F
# 9964         PI  C00401224                       J1200  WebDA     Q     F
# 10378        PI  C00401224                       J1200  WebDA     Q     F
# 10447        PI  C00401224                NaN    J1200  WebDA     Q     F
# 10637        PI  C00401224                       J1200  WebDA     Q     F
# 10743        PI  C00401224                       J1200  WebDA     Q     F
# 10914        PI  C00401224                NaN    J1200  WebDA     M     F
# 10921        PI  C00401224                       J1200  WebDA     Q     F
#
#       csource viewpt comments state
# 31      WebDA      L             MA
# 646     WebDA      L             MA
# 1310    WebDA      L             MA
# 2779    WebDA      L             MA
# 2781    WebDA      L             MA
# 2840    WebDA      L             MA
# 2879    WebDA      L             MA
# 3349    WebDA      L             MA
# 4012    WebDA      L             MA
# 4522    WebDA      L             MA
# 4781    WebDA      L             MA
# 5291    WebDA      L             MA
# 5514    WebDA      L             MA
# 5789    WebDA      L             MA
# 6064    WebDA      L             MA
# 6728    WebDA      L             MA
# 7810    WebDA      L             MA
# 7901    WebDA      L             MA
# 8151    WebDA      L             MA
# 8386    WebDA      L             MA
# 8812    WebDA      L             MA
# 8922    WebDA      L             MA
# 9147    WebDA      L             MA
# 9964    WebDA      L             MA
# 10378   WebDA      L             MA
# 10447   WebDA      L             MA
# 10637   WebDA      L             MA
# 10743   WebDA      L             MA
# 10914   WebDA      L             MA
# 10921   WebDA      L             MA
